# %% [markdown]
# ### U-net with simple Resnet Blocks v2, can get 0.80+
# * Original version :
#   https://www.kaggle.com/shaojiaxin/u-net-with-simple-resnet-blocks
#
#
# #### update log
# 1.   Cancel last dropout (seems better)
# 2.  modify convolution_block, to be more consistant with the standard resent model.
#       * https://arxiv.org/abs/1603.05027
# 3. Use faster  IOU metric score code,
#       * https://www.kaggle.com/donchuk/fast-implementation-of-scoring-metric
# 4. Use  binary_crossentropy loss and then Lovász-hinge loss (very slow!)
#      * Lovász-hinge loss: https://github.com/bermanmaxim/LovaszSoftmax
#
# Limit the max epochs number to make the kernel finish in the limit of 6 hours, better score can be achived at more epochs

# %%
import os
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

# import cv2
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
version = 5
basic_name = f'Unet_resnet_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# Unet_resnet_v5.model
# Unet_resnet_v5.csv

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):# not used
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("data/salt/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("data/salt/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("data/salt/train/images/{}.png".format(idx), 
                                        grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/szelee/anaconda3/envs/tf/lib/python3.6/site-packages/keras_preprocessing/image.py:489: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
train_df["masks"] = [np.array(load_img("data/salt/train/masks/{}.png".format(idx), 
                                       grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/szelee/anaconda3/envs/tf/lib/python3.6/site-packages/keras_preprocessing/image.py:489: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5, 0, 'Coverage class')

# %%
#Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5, 1.0, 'Depth distribution')

# %%
# Create train/validation split stratified by salt coverage

ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state= 1234)

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.4):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
#             metric.append(1)
#             continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
#Data augmentation
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.5)

model1 = Model(input_layer, output_layer)

c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

#model1.summary()

# %%
#early_stopping = EarlyStopping(monitor='my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode = 'max',factor=0.6, patience=5, min_lr=0.0001, verbose=1)

epochs = 200
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr], 
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
#  - 103s - loss: 0.4843 - my_iou_metric: 0.2954 - val_loss: 0.8715 - val_my_iou_metric: 0.3700
#
# Epoch 00001: my_iou_metric improved from -inf to 0.29544, saving model to Unet_resnet_v5.model
# Epoch 2/200
#  - 88s - loss: 0.3920 - my_iou_metric: 0.4315 - val_loss: 0.6081 - val_my_iou_metric: 0.3526
#
# Epoch 00002: my_iou_metric improved from 0.29544 to 0.43152, saving model to Unet_resnet_v5.model
# Epoch 3/200
#  - 88s - loss: 0.3478 - my_iou_metric: 0.4810 - val_loss: 0.9925 - val_my_iou_metric: 0.3900
#
# Epoch 00003: my_iou_metric improved from 0.43152 to 0.48095, saving model to Unet_resnet_v5.model
# Epoch 4/200
#  - 88s - loss: 0.3298 - my_iou_metric: 0.5241 - val_loss: 0.5062 - val_my_iou_metric: 0.3755
#
# Epoch 00004: my_iou_metric improved from 0.48095 to 0.52409, saving model to Unet_resnet_v5.model
# Epoch 5/200
#  - 88s - loss: 0.3468 - my_iou_metric: 0.5020 - val_loss: 0.7715 - val_my_iou_metric: 0.3900
#
# Epoch 00005: my_iou_metric did not improve from 0.52409
# Epoch 6/200
#  - 88s - loss: 0.3055 - my_iou_metric: 0.5428 - val_loss: 1.0186 - val_my_iou_metric: 0.3887
#
# Epoch 00006: my_iou_metric improved from 0.52409 to 0.54283, saving model to Unet_resnet_v5.model
# Epoch 7/200
#  - 88s - loss: 0.2654 - my_iou_metric: 0.5733 - val_loss: 0.2814 - val_my_iou_metric: 0.5370
#
# Epoch 00007: my_iou_metric improved from 0.54283 to 0.57334, saving model to Unet_resnet_v5.model
# Epoch 8/200
#  - 89s - loss: 0.2485 - my_iou_metric: 0.5837 - val_loss: 0.2563 - val_my_iou_metric: 0.6268
#
# Epoch 00008: my_iou_metric improved from 0.57334 to 0.58375, saving model to Unet_resnet_v5.model
# Epoch 9/200
#  - 88s - loss: 0.2242 - my_iou_metric: 0.6080 - val_loss: 0.2615 - val_my_iou_metric: 0.6225
#
# Epoch 00009: my_iou_metric improved from 0.58375 to 0.60800, saving model to Unet_resnet_v5.model
# Epoch 10/200
#  - 88s - loss: 0.2110 - my_iou_metric: 0.6306 - val_loss: 0.2687 - val_my_iou_metric: 0.6266
#
# Epoch 00010: my_iou_metric improved from 0.60800 to 0.63061, saving model to Unet_resnet_v5.model
# Epoch 11/200
#  - 88s - loss: 0.1994 - my_iou_metric: 0.6419 - val_loss: 0.2243 - val_my_iou_metric: 0.6509
#
# Epoch 00011: my_iou_metric improved from 0.63061 to 0.64189, saving model to Unet_resnet_v5.model
# Epoch 12/200
#  - 89s - loss: 0.1885 - my_iou_metric: 0.6578 - val_loss: 0.3447 - val_my_iou_metric: 0.5365
#
# Epoch 00012: my_iou_metric improved from 0.64189 to 0.65783, saving model to Unet_resnet_v5.model
# Epoch 13/200
#  - 89s - loss: 0.1831 - my_iou_metric: 0.6664 - val_loss: 0.1962 - val_my_iou_metric: 0.6461
#
# Epoch 00013: my_iou_metric improved from 0.65783 to 0.66641, saving model to Unet_resnet_v5.model
# Epoch 14/200
#  - 88s - loss: 0.1694 - my_iou_metric: 0.6811 - val_loss: 0.1952 - val_my_iou_metric: 0.6789
#
# Epoch 00014: my_iou_metric improved from 0.66641 to 0.68112, saving model to Unet_resnet_v5.model
# Epoch 15/200
#  - 89s - loss: 0.1692 - my_iou_metric: 0.6859 - val_loss: 0.1758 - val_my_iou_metric: 0.7120
#
# Epoch 00015: my_iou_metric improved from 0.68112 to 0.68587, saving model to Unet_resnet_v5.model
# Epoch 16/200
#  - 88s - loss: 0.1664 - my_iou_metric: 0.6878 - val_loss: 0.1756 - val_my_iou_metric: 0.6840
#
# Epoch 00016: my_iou_metric improved from 0.68587 to 0.68780, saving model to Unet_resnet_v5.model
# Epoch 17/200
#  - 88s - loss: 0.1693 - my_iou_metric: 0.6885 - val_loss: 0.1962 - val_my_iou_metric: 0.6810
#
# Epoch 00017: my_iou_metric improved from 0.68780 to 0.68845, saving model to Unet_resnet_v5.model
# Epoch 18/200
#  - 89s - loss: 0.1628 - my_iou_metric: 0.6927 - val_loss: 0.1748 - val_my_iou_metric: 0.7050
#
# Epoch 00018: my_iou_metric improved from 0.68845 to 0.69267, saving model to Unet_resnet_v5.model
# Epoch 19/200
#  - 89s - loss: 0.1581 - my_iou_metric: 0.7031 - val_loss: 0.6261 - val_my_iou_metric: 0.4470
#
# Epoch 00019: my_iou_metric improved from 0.69267 to 0.70311, saving model to Unet_resnet_v5.model
# Epoch 20/200
#  - 89s - loss: 0.1533 - my_iou_metric: 0.7001 - val_loss: 0.2119 - val_my_iou_metric: 0.6971
#
# Epoch 00020: my_iou_metric did not improve from 0.70311
# Epoch 21/200
#  - 88s - loss: 0.1496 - my_iou_metric: 0.7140 - val_loss: 0.2392 - val_my_iou_metric: 0.6300
#
# Epoch 00021: my_iou_metric improved from 0.70311 to 0.71402, saving model to Unet_resnet_v5.model
# Epoch 22/200
#  - 89s - loss: 0.1446 - my_iou_metric: 0.7146 - val_loss: 0.2477 - val_my_iou_metric: 0.6343
#
# Epoch 00022: my_iou_metric improved from 0.71402 to 0.71464, saving model to Unet_resnet_v5.model
# Epoch 23/200
#  - 89s - loss: 0.1456 - my_iou_metric: 0.7187 - val_loss: 0.1771 - val_my_iou_metric: 0.7238
#
# Epoch 00023: my_iou_metric improved from 0.71464 to 0.71867, saving model to Unet_resnet_v5.model
# Epoch 24/200
#  - 88s - loss: 0.1392 - my_iou_metric: 0.7208 - val_loss: 0.5181 - val_my_iou_metric: 0.5590
#
# Epoch 00024: my_iou_metric improved from 0.71867 to 0.72081, saving model to Unet_resnet_v5.model
# Epoch 25/200
#  - 89s - loss: 0.1351 - my_iou_metric: 0.7309 - val_loss: 0.1621 - val_my_iou_metric: 0.7251
#
# Epoch 00025: my_iou_metric improved from 0.72081 to 0.73091, saving model to Unet_resnet_v5.model
# Epoch 26/200
#  - 89s - loss: 0.1405 - my_iou_metric: 0.7256 - val_loss: 0.8621 - val_my_iou_metric: 0.3869
#
# Epoch 00026: my_iou_metric did not improve from 0.73091
# Epoch 27/200
#  - 89s - loss: 0.1420 - my_iou_metric: 0.7222 - val_loss: 0.2286 - val_my_iou_metric: 0.6415
#
# Epoch 00027: my_iou_metric did not improve from 0.73091
# Epoch 28/200
#  - 88s - loss: 0.1338 - my_iou_metric: 0.7259 - val_loss: 0.2169 - val_my_iou_metric: 0.6731
#
# Epoch 00028: my_iou_metric did not improve from 0.73091
# Epoch 29/200
#  - 88s - loss: 0.1288 - my_iou_metric: 0.7371 - val_loss: 0.1558 - val_my_iou_metric: 0.7366
#
# Epoch 00029: my_iou_metric improved from 0.73091 to 0.73709, saving model to Unet_resnet_v5.model
# Epoch 30/200
#  - 89s - loss: 0.1282 - my_iou_metric: 0.7413 - val_loss: 0.1681 - val_my_iou_metric: 0.7348
#
# Epoch 00030: my_iou_metric improved from 0.73709 to 0.74125, saving model to Unet_resnet_v5.model
# Epoch 31/200
#  - 88s - loss: 0.1199 - my_iou_metric: 0.7497 - val_loss: 0.1769 - val_my_iou_metric: 0.7101
#
# Epoch 00031: my_iou_metric improved from 0.74125 to 0.74970, saving model to Unet_resnet_v5.model
# Epoch 32/200
#  - 88s - loss: 0.1267 - my_iou_metric: 0.7391 - val_loss: 0.1476 - val_my_iou_metric: 0.7422
#
# Epoch 00032: my_iou_metric did not improve from 0.74970
# Epoch 33/200
#  - 88s - loss: 0.1239 - my_iou_metric: 0.7434 - val_loss: 0.3397 - val_my_iou_metric: 0.6199
#
# Epoch 00033: my_iou_metric did not improve from 0.74970
# Epoch 34/200
#  - 88s - loss: 0.1195 - my_iou_metric: 0.7462 - val_loss: 0.1494 - val_my_iou_metric: 0.7315
#
# Epoch 00034: my_iou_metric did not improve from 0.74970
# Epoch 35/200
#  - 88s - loss: 0.1164 - my_iou_metric: 0.7502 - val_loss: 0.2051 - val_my_iou_metric: 0.6746
#
# Epoch 00035: my_iou_metric improved from 0.74970 to 0.75022, saving model to Unet_resnet_v5.model
# Epoch 36/200
#  - 89s - loss: 0.1144 - my_iou_metric: 0.7521 - val_loss: 0.3600 - val_my_iou_metric: 0.6485
#
# Epoch 00036: my_iou_metric improved from 0.75022 to 0.75206, saving model to Unet_resnet_v5.model
# Epoch 37/200
#  - 89s - loss: 0.1106 - my_iou_metric: 0.7573 - val_loss: 0.1411 - val_my_iou_metric: 0.7634
#
# Epoch 00037: my_iou_metric improved from 0.75206 to 0.75734, saving model to Unet_resnet_v5.model
# Epoch 38/200
#  - 88s - loss: 0.1144 - my_iou_metric: 0.7516 - val_loss: 0.1674 - val_my_iou_metric: 0.7315
#
# Epoch 00038: my_iou_metric did not improve from 0.75734
# Epoch 39/200
#  - 89s - loss: 0.1112 - my_iou_metric: 0.7574 - val_loss: 0.3750 - val_my_iou_metric: 0.5614
#
# Epoch 00039: my_iou_metric improved from 0.75734 to 0.75739, saving model to Unet_resnet_v5.model
# Epoch 40/200
#  - 89s - loss: 0.1097 - my_iou_metric: 0.7585 - val_loss: 0.1665 - val_my_iou_metric: 0.7367
#
# Epoch 00040: my_iou_metric improved from 0.75739 to 0.75855, saving model to Unet_resnet_v5.model
# Epoch 41/200
#  - 89s - loss: 0.1051 - my_iou_metric: 0.7608 - val_loss: 0.1562 - val_my_iou_metric: 0.7333
#
# Epoch 00041: my_iou_metric improved from 0.75855 to 0.76075, saving model to Unet_resnet_v5.model
# Epoch 42/200
#  - 88s - loss: 0.1085 - my_iou_metric: 0.7562 - val_loss: 0.1666 - val_my_iou_metric: 0.7390
#
# Epoch 00042: my_iou_metric did not improve from 0.76075
# Epoch 43/200
#  - 89s - loss: 0.1021 - my_iou_metric: 0.7663 - val_loss: 0.3255 - val_my_iou_metric: 0.6995
#
# Epoch 00043: my_iou_metric improved from 0.76075 to 0.76631, saving model to Unet_resnet_v5.model
# Epoch 44/200
#  - 89s - loss: 0.1037 - my_iou_metric: 0.7699 - val_loss: 0.1368 - val_my_iou_metric: 0.7526
#
# Epoch 00044: my_iou_metric improved from 0.76631 to 0.76987, saving model to Unet_resnet_v5.model
# Epoch 45/200
#  - 88s - loss: 0.0975 - my_iou_metric: 0.7706 - val_loss: 0.1537 - val_my_iou_metric: 0.7536
#
# Epoch 00045: my_iou_metric improved from 0.76987 to 0.77061, saving model to Unet_resnet_v5.model
# Epoch 46/200
#  - 88s - loss: 0.1052 - my_iou_metric: 0.7579 - val_loss: 0.1717 - val_my_iou_metric: 0.7451
#
# Epoch 00046: my_iou_metric did not improve from 0.77061
# Epoch 47/200
#  - 89s - loss: 0.0954 - my_iou_metric: 0.7739 - val_loss: 0.1557 - val_my_iou_metric: 0.7479
#
# Epoch 00047: my_iou_metric improved from 0.77061 to 0.77392, saving model to Unet_resnet_v5.model
# Epoch 48/200
#  - 89s - loss: 0.1009 - my_iou_metric: 0.7673 - val_loss: 0.1605 - val_my_iou_metric: 0.7319
#
# Epoch 00048: my_iou_metric did not improve from 0.77392
# Epoch 49/200
#  - 87s - loss: 0.1040 - my_iou_metric: 0.7661 - val_loss: 0.1610 - val_my_iou_metric: 0.7210
#
# Epoch 00049: my_iou_metric did not improve from 0.77392
# Epoch 50/200
#  - 87s - loss: 0.1021 - my_iou_metric: 0.7654 - val_loss: 0.2709 - val_my_iou_metric: 0.6577
#
# Epoch 00050: my_iou_metric did not improve from 0.77392
# Epoch 51/200
#  - 87s - loss: 0.0919 - my_iou_metric: 0.7769 - val_loss: 0.1556 - val_my_iou_metric: 0.7622
#
# Epoch 00051: my_iou_metric improved from 0.77392 to 0.77686, saving model to Unet_resnet_v5.model
# Epoch 52/200
#  - 87s - loss: 0.0916 - my_iou_metric: 0.7802 - val_loss: 0.1569 - val_my_iou_metric: 0.7552
#
# Epoch 00052: my_iou_metric improved from 0.77686 to 0.78016, saving model to Unet_resnet_v5.model
# Epoch 53/200
#  - 88s - loss: 0.0893 - my_iou_metric: 0.7803 - val_loss: 0.1292 - val_my_iou_metric: 0.7709
#
# Epoch 00053: my_iou_metric improved from 0.78016 to 0.78033, saving model to Unet_resnet_v5.model
# Epoch 54/200
#  - 89s - loss: 0.0857 - my_iou_metric: 0.7850 - val_loss: 0.1437 - val_my_iou_metric: 0.7664
#
# Epoch 00054: my_iou_metric improved from 0.78033 to 0.78495, saving model to Unet_resnet_v5.model
# Epoch 55/200
#  - 88s - loss: 0.0892 - my_iou_metric: 0.7813 - val_loss: 0.1622 - val_my_iou_metric: 0.7556
#
# Epoch 00055: my_iou_metric did not improve from 0.78495
# Epoch 56/200
#  - 88s - loss: 0.0871 - my_iou_metric: 0.7851 - val_loss: 0.1366 - val_my_iou_metric: 0.7735
#
# Epoch 00056: my_iou_metric improved from 0.78495 to 0.78509, saving model to Unet_resnet_v5.model
# Epoch 57/200
#  - 89s - loss: 0.0825 - my_iou_metric: 0.7862 - val_loss: 0.1607 - val_my_iou_metric: 0.7632
#
# Epoch 00057: my_iou_metric improved from 0.78509 to 0.78623, saving model to Unet_resnet_v5.model
# Epoch 58/200
#  - 89s - loss: 0.0876 - my_iou_metric: 0.7792 - val_loss: 0.2972 - val_my_iou_metric: 0.6706
#
# Epoch 00058: my_iou_metric did not improve from 0.78623
# Epoch 59/200
#  - 88s - loss: 0.0847 - my_iou_metric: 0.7814 - val_loss: 0.1644 - val_my_iou_metric: 0.7218
#
# Epoch 00059: my_iou_metric did not improve from 0.78623
# Epoch 60/200
#  - 88s - loss: 0.0839 - my_iou_metric: 0.7832 - val_loss: 0.1652 - val_my_iou_metric: 0.7580
#
# Epoch 00060: my_iou_metric did not improve from 0.78623
# Epoch 61/200
#  - 88s - loss: 0.0742 - my_iou_metric: 0.7918 - val_loss: 0.1436 - val_my_iou_metric: 0.7784
#
# Epoch 00061: my_iou_metric improved from 0.78623 to 0.79180, saving model to Unet_resnet_v5.model
# Epoch 62/200
#  - 88s - loss: 0.0768 - my_iou_metric: 0.7859 - val_loss: 0.1659 - val_my_iou_metric: 0.7688
#
# Epoch 00062: my_iou_metric did not improve from 0.79180
# Epoch 63/200
#  - 88s - loss: 0.0793 - my_iou_metric: 0.7937 - val_loss: 0.1449 - val_my_iou_metric: 0.7675
#
# Epoch 00063: my_iou_metric improved from 0.79180 to 0.79375, saving model to Unet_resnet_v5.model
# Epoch 64/200
#  - 88s - loss: 0.0767 - my_iou_metric: 0.7952 - val_loss: 0.1648 - val_my_iou_metric: 0.7468
#
# Epoch 00064: my_iou_metric improved from 0.79375 to 0.79520, saving model to Unet_resnet_v5.model
# Epoch 65/200
#  - 88s - loss: 0.0748 - my_iou_metric: 0.7941 - val_loss: 0.1458 - val_my_iou_metric: 0.7724
#
# Epoch 00065: my_iou_metric did not improve from 0.79520
# Epoch 66/200
#  - 88s - loss: 0.0771 - my_iou_metric: 0.7943 - val_loss: 0.1438 - val_my_iou_metric: 0.7623
#
# Epoch 00066: my_iou_metric did not improve from 0.79520
# Epoch 67/200
#  - 88s - loss: 0.0783 - my_iou_metric: 0.7893 - val_loss: 0.1746 - val_my_iou_metric: 0.7516
#
# Epoch 00067: my_iou_metric did not improve from 0.79520
# Epoch 68/200
#  - 88s - loss: 0.0737 - my_iou_metric: 0.7962 - val_loss: 0.1415 - val_my_iou_metric: 0.7496
#
# Epoch 00068: my_iou_metric improved from 0.79520 to 0.79620, saving model to Unet_resnet_v5.model
# Epoch 69/200
#  - 89s - loss: 0.0705 - my_iou_metric: 0.8019 - val_loss: 0.1471 - val_my_iou_metric: 0.7671
#
# Epoch 00069: my_iou_metric improved from 0.79620 to 0.80189, saving model to Unet_resnet_v5.model
# Epoch 70/200
#  - 88s - loss: 0.0671 - my_iou_metric: 0.8008 - val_loss: 0.1528 - val_my_iou_metric: 0.7665
#
# Epoch 00070: my_iou_metric did not improve from 0.80189
# Epoch 71/200
#  - 89s - loss: 0.0714 - my_iou_metric: 0.7969 - val_loss: 0.1700 - val_my_iou_metric: 0.7471
#
# Epoch 00071: my_iou_metric did not improve from 0.80189
# Epoch 72/200
#  - 89s - loss: 0.0714 - my_iou_metric: 0.8011 - val_loss: 0.1444 - val_my_iou_metric: 0.7712
#
# Epoch 00072: my_iou_metric did not improve from 0.80189
# Epoch 73/200
#  - 88s - loss: 0.0693 - my_iou_metric: 0.7967 - val_loss: 0.1499 - val_my_iou_metric: 0.7647
#
# Epoch 00073: my_iou_metric did not improve from 0.80189
# Epoch 74/200
#  - 88s - loss: 0.0689 - my_iou_metric: 0.7995 - val_loss: 0.1705 - val_my_iou_metric: 0.7572
#
# Epoch 00074: my_iou_metric did not improve from 0.80189
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# Epoch 75/200
#  - 88s - loss: 0.0562 - my_iou_metric: 0.8153 - val_loss: 0.1455 - val_my_iou_metric: 0.7794
#
# Epoch 00075: my_iou_metric improved from 0.80189 to 0.81534, saving model to Unet_resnet_v5.model
# Epoch 76/200
#  - 88s - loss: 0.0561 - my_iou_metric: 0.8182 - val_loss: 0.1436 - val_my_iou_metric: 0.7796
#
# Epoch 00076: my_iou_metric improved from 0.81534 to 0.81823, saving model to Unet_resnet_v5.model
# Epoch 77/200
#  - 88s - loss: 0.0541 - my_iou_metric: 0.8203 - val_loss: 0.1231 - val_my_iou_metric: 0.7761
#
# Epoch 00077: my_iou_metric improved from 0.81823 to 0.82033, saving model to Unet_resnet_v5.model
# Epoch 78/200
#  - 88s - loss: 0.0532 - my_iou_metric: 0.8207 - val_loss: 0.1602 - val_my_iou_metric: 0.7747
#
# Epoch 00078: my_iou_metric improved from 0.82033 to 0.82069, saving model to Unet_resnet_v5.model
# Epoch 79/200
#  - 88s - loss: 0.0518 - my_iou_metric: 0.8251 - val_loss: 0.5583 - val_my_iou_metric: 0.5334
#
# Epoch 00079: my_iou_metric improved from 0.82069 to 0.82509, saving model to Unet_resnet_v5.model
# Epoch 80/200
#  - 88s - loss: 0.0538 - my_iou_metric: 0.8163 - val_loss: 0.1843 - val_my_iou_metric: 0.7581
#
# Epoch 00080: my_iou_metric did not improve from 0.82509
# Epoch 81/200
#  - 88s - loss: 0.0506 - my_iou_metric: 0.8204 - val_loss: 0.1774 - val_my_iou_metric: 0.7586
#
# Epoch 00081: my_iou_metric did not improve from 0.82509
# Epoch 82/200
#  - 88s - loss: 0.0503 - my_iou_metric: 0.8249 - val_loss: 0.1840 - val_my_iou_metric: 0.7569
#
# Epoch 00082: my_iou_metric did not improve from 0.82509
# Epoch 83/200
#  - 88s - loss: 0.0490 - my_iou_metric: 0.8260 - val_loss: 0.1744 - val_my_iou_metric: 0.7706
#
# Epoch 00083: my_iou_metric improved from 0.82509 to 0.82605, saving model to Unet_resnet_v5.model
# Epoch 84/200
#  - 88s - loss: 0.0476 - my_iou_metric: 0.8313 - val_loss: 0.1753 - val_my_iou_metric: 0.7792
#
# Epoch 00084: my_iou_metric improved from 0.82605 to 0.83134, saving model to Unet_resnet_v5.model
# Epoch 85/200
#  - 88s - loss: 0.0537 - my_iou_metric: 0.8219 - val_loss: 0.2288 - val_my_iou_metric: 0.7495
#
# Epoch 00085: my_iou_metric did not improve from 0.83134
# Epoch 86/200
#  - 88s - loss: 0.0535 - my_iou_metric: 0.8219 - val_loss: 0.1947 - val_my_iou_metric: 0.7596
#
# Epoch 00086: my_iou_metric did not improve from 0.83134
# Epoch 87/200
#  - 88s - loss: 0.0482 - my_iou_metric: 0.8234 - val_loss: 0.1582 - val_my_iou_metric: 0.7693
# Epoch 00087: my_iou_metric did not improve from 0.83134
# Epoch 88/200
#  - 88s - loss: 0.0510 - my_iou_metric: 0.8218 - val_loss: 0.1548 - val_my_iou_metric: 0.7814
#
# Epoch 00088: my_iou_metric did not improve from 0.83134
# Epoch 89/200
#  - 88s - loss: 0.0458 - my_iou_metric: 0.8301 - val_loss: 0.1744 - val_my_iou_metric: 0.7686
#
# Epoch 00089: my_iou_metric did not improve from 0.83134
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# Epoch 90/200
#  - 88s - loss: 0.0410 - my_iou_metric: 0.8344 - val_loss: 0.1708 - val_my_iou_metric: 0.7860
#
# Epoch 00090: my_iou_metric improved from 0.83134 to 0.83444, saving model to Unet_resnet_v5.model
# Epoch 91/200
#  - 88s - loss: 0.0409 - my_iou_metric: 0.8374 - val_loss: 0.1699 - val_my_iou_metric: 0.7870
#
# Epoch 00091: my_iou_metric improved from 0.83444 to 0.83741, saving model to Unet_resnet_v5.model
# Epoch 92/200
#  - 88s - loss: 0.0428 - my_iou_metric: 0.8378 - val_loss: 0.1742 - val_my_iou_metric: 0.7825
#
# Epoch 00092: my_iou_metric improved from 0.83741 to 0.83784, saving model to Unet_resnet_v5.model
# Epoch 93/200
#  - 88s - loss: 0.0399 - my_iou_metric: 0.8381 - val_loss: 0.1604 - val_my_iou_metric: 0.7784
#
# Epoch 00093: my_iou_metric improved from 0.83784 to 0.83806, saving model to Unet_resnet_v5.model
# Epoch 94/200
#  - 88s - loss: 0.0365 - my_iou_metric: 0.8477 - val_loss: 0.1709 - val_my_iou_metric: 0.7911
#
# Epoch 00094: my_iou_metric improved from 0.83806 to 0.84769, saving model to Unet_resnet_v5.model
# Epoch 95/200
#  - 88s - loss: 0.0367 - my_iou_metric: 0.8466 - val_loss: 0.1699 - val_my_iou_metric: 0.7849
#
# Epoch 00095: my_iou_metric did not improve from 0.84769
# Epoch 96/200
#  - 88s - loss: 0.0397 - my_iou_metric: 0.8413 - val_loss: 0.1780 - val_my_iou_metric: 0.7725
#
# Epoch 00096: my_iou_metric did not improve from 0.84769
# Epoch 97/200
#  - 88s - loss: 0.0401 - my_iou_metric: 0.8412 - val_loss: 0.1785 - val_my_iou_metric: 0.7826
#
# Epoch 00097: my_iou_metric did not improve from 0.84769
# Epoch 98/200
#  - 88s - loss: 0.0369 - my_iou_metric: 0.8446 - val_loss: 0.1971 - val_my_iou_metric: 0.7860
#
# Epoch 00098: my_iou_metric did not improve from 0.84769
# Epoch 99/200
#  - 88s - loss: 0.0365 - my_iou_metric: 0.8465 - val_loss: 0.2006 - val_my_iou_metric: 0.7644
#
# Epoch 00099: my_iou_metric did not improve from 0.84769
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# Epoch 100/200
#  - 88s - loss: 0.0363 - my_iou_metric: 0.8507 - val_loss: 0.1698 - val_my_iou_metric: 0.7885
#
# Epoch 00100: my_iou_metric improved from 0.84769 to 0.85069, saving model to Unet_resnet_v5.model
# Epoch 101/200
#  - 87s - loss: 0.0339 - my_iou_metric: 0.8505 - val_loss: 0.1876 - val_my_iou_metric: 0.7847
#
# Epoch 00101: my_iou_metric did not improve from 0.85069
# Epoch 102/200
#  - 88s - loss: 0.0338 - my_iou_metric: 0.8498 - val_loss: 0.1935 - val_my_iou_metric: 0.7925
#
# Epoch 00102: my_iou_metric did not improve from 0.85069
# Epoch 103/200
#  - 88s - loss: 0.0340 - my_iou_metric: 0.8502 - val_loss: 0.1867 - val_my_iou_metric: 0.7915
#
# Epoch 00103: my_iou_metric did not improve from 0.85069
# Epoch 104/200
#  - 88s - loss: 0.0326 - my_iou_metric: 0.8532 - val_loss: 0.1873 - val_my_iou_metric: 0.7870
#
# Epoch 00104: my_iou_metric improved from 0.85069 to 0.85317, saving model to Unet_resnet_v5.model
# Epoch 105/200
#  - 87s - loss: 0.0336 - my_iou_metric: 0.8504 - val_loss: 0.1923 - val_my_iou_metric: 0.7879
#
# Epoch 00105: my_iou_metric did not improve from 0.85317
# Epoch 106/200
#  - 87s - loss: 0.0330 - my_iou_metric: 0.8517 - val_loss: 0.1962 - val_my_iou_metric: 0.7852
#
# Epoch 00106: my_iou_metric did not improve from 0.85317
# Epoch 107/200
#  - 88s - loss: 0.0326 - my_iou_metric: 0.8537 - val_loss: 0.1919 - val_my_iou_metric: 0.7922
#
# Epoch 00107: my_iou_metric improved from 0.85317 to 0.85369, saving model to Unet_resnet_v5.model
# Epoch 108/200
#  - 88s - loss: 0.0330 - my_iou_metric: 0.8536 - val_loss: 0.1757 - val_my_iou_metric: 0.7940
#
# Epoch 00108: my_iou_metric did not improve from 0.85369
# Epoch 109/200
#  - 88s - loss: 0.0321 - my_iou_metric: 0.8535 - val_loss: 0.1957 - val_my_iou_metric: 0.7933
#
# Epoch 00109: my_iou_metric did not improve from 0.85369
# Epoch 110/200
#  - 88s - loss: 0.0312 - my_iou_metric: 0.8572 - val_loss: 0.1901 - val_my_iou_metric: 0.7860
#
# Epoch 00110: my_iou_metric improved from 0.85369 to 0.85716, saving model to Unet_resnet_v5.model
# Epoch 111/200
#  - 88s - loss: 0.0327 - my_iou_metric: 0.8543 - val_loss: 0.2045 - val_my_iou_metric: 0.7880
#
# Epoch 00111: my_iou_metric did not improve from 0.85716
# Epoch 112/200
#  - 88s - loss: 0.0349 - my_iou_metric: 0.8529 - val_loss: 0.1857 - val_my_iou_metric: 0.7756
#
# Epoch 00112: my_iou_metric did not improve from 0.85716
# Epoch 113/200
#  - 89s - loss: 0.0332 - my_iou_metric: 0.8533 - val_loss: 0.1790 - val_my_iou_metric: 0.7854
#
# Epoch 00113: my_iou_metric did not improve from 0.85716
# Epoch 114/200
#  - 89s - loss: 0.0317 - my_iou_metric: 0.8548 - val_loss: 0.1841 - val_my_iou_metric: 0.7914
#
# Epoch 00114: my_iou_metric did not improve from 0.85716
# Epoch 115/200
#  - 88s - loss: 0.0311 - my_iou_metric: 0.8552 - val_loss: 0.2047 - val_my_iou_metric: 0.7909
#
# Epoch 00115: my_iou_metric did not improve from 0.85716
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# Epoch 116/200
#  - 89s - loss: 0.0299 - my_iou_metric: 0.8588 - val_loss: 0.2051 - val_my_iou_metric: 0.7904
#
# Epoch 00116: my_iou_metric improved from 0.85716 to 0.85877, saving model to Unet_resnet_v5.model
# Epoch 117/200
#  - 89s - loss: 0.0315 - my_iou_metric: 0.8545 - val_loss: 0.2023 - val_my_iou_metric: 0.7821
#
# Epoch 00117: my_iou_metric did not improve from 0.85877
# Epoch 118/200
#  - 89s - loss: 0.0292 - my_iou_metric: 0.8602 - val_loss: 0.1998 - val_my_iou_metric: 0.7905
#
# Epoch 00118: my_iou_metric improved from 0.85877 to 0.86017, saving model to Unet_resnet_v5.model
# Epoch 119/200
#  - 88s - loss: 0.0299 - my_iou_metric: 0.8597 - val_loss: 0.1976 - val_my_iou_metric: 0.7881
#
# Epoch 00119: my_iou_metric did not improve from 0.86017
# Epoch 120/200
#  - 89s - loss: 0.0295 - my_iou_metric: 0.8588 - val_loss: 0.2113 - val_my_iou_metric: 0.7898
#
# Epoch 00120: my_iou_metric did not improve from 0.86017
# Epoch 121/200
#  - 89s - loss: 0.0301 - my_iou_metric: 0.8590 - val_loss: 0.2142 - val_my_iou_metric: 0.7832
#
# Epoch 00121: my_iou_metric did not improve from 0.86017
# Epoch 122/200
#  - 88s - loss: 0.0305 - my_iou_metric: 0.8572 - val_loss: 0.2079 - val_my_iou_metric: 0.7872
#
# Epoch 00122: my_iou_metric did not improve from 0.86017
# Epoch 123/200
#  - 89s - loss: 0.0303 - my_iou_metric: 0.8603 - val_loss: 0.1818 - val_my_iou_metric: 0.7924
#
# Epoch 00123: my_iou_metric improved from 0.86017 to 0.86030, saving model to Unet_resnet_v5.model
# Epoch 124/200
#  - 89s - loss: 0.0295 - my_iou_metric: 0.8605 - val_loss: 0.1896 - val_my_iou_metric: 0.7885
#
# Epoch 00124: my_iou_metric improved from 0.86030 to 0.86045, saving model to Unet_resnet_v5.model
# Epoch 125/200
#  - 89s - loss: 0.0284 - my_iou_metric: 0.8622 - val_loss: 0.2047 - val_my_iou_metric: 0.7926
#
# Epoch 00125: my_iou_metric improved from 0.86045 to 0.86222, saving model to Unet_resnet_v5.model
# Epoch 126/200
#  - 88s - loss: 0.0291 - my_iou_metric: 0.8611 - val_loss: 0.2129 - val_my_iou_metric: 0.7870
#
# Epoch 00126: my_iou_metric did not improve from 0.86222
# Epoch 127/200
#  - 89s - loss: 0.0287 - my_iou_metric: 0.8602 - val_loss: 0.2022 - val_my_iou_metric: 0.7890
#
# Epoch 00127: my_iou_metric did not improve from 0.86222
# Epoch 128/200
#  - 89s - loss: 0.0291 - my_iou_metric: 0.8628 - val_loss: 0.2044 - val_my_iou_metric: 0.7867
#
# Epoch 00128: my_iou_metric improved from 0.86222 to 0.86275, saving model to Unet_resnet_v5.model
# Epoch 129/200
#  - 88s - loss: 0.0298 - my_iou_metric: 0.8606 - val_loss: 0.1955 - val_my_iou_metric: 0.7863
#
# Epoch 00129: my_iou_metric did not improve from 0.86275
# Epoch 130/200
#  - 89s - loss: 0.0279 - my_iou_metric: 0.8661 - val_loss: 0.2187 - val_my_iou_metric: 0.7867
#
# Epoch 00130: my_iou_metric improved from 0.86275 to 0.86611, saving model to Unet_resnet_v5.model
# Epoch 131/200
#  - 89s - loss: 0.0288 - my_iou_metric: 0.8602 - val_loss: 0.2044 - val_my_iou_metric: 0.7900
#
# Epoch 00131: my_iou_metric did not improve from 0.86611
# Epoch 132/200
#  - 89s - loss: 0.0286 - my_iou_metric: 0.8593 - val_loss: 0.2003 - val_my_iou_metric: 0.7863
# Epoch 00132: my_iou_metric did not improve from 0.86611
# Epoch 133/200
#  - 88s - loss: 0.0278 - my_iou_metric: 0.8653 - val_loss: 0.2080 - val_my_iou_metric: 0.7899
#
# Epoch 00133: my_iou_metric did not improve from 0.86611
# Epoch 134/200
#  - 89s - loss: 0.0274 - my_iou_metric: 0.8641 - val_loss: 0.2099 - val_my_iou_metric: 0.7934
#
# Epoch 00134: my_iou_metric did not improve from 0.86611
# Epoch 135/200
#  - 89s - loss: 0.0284 - my_iou_metric: 0.8633 - val_loss: 0.1979 - val_my_iou_metric: 0.7864
#
# Epoch 00135: my_iou_metric did not improve from 0.86611
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 0.0007775999838486314.
# Epoch 136/200
#  - 88s - loss: 0.0275 - my_iou_metric: 0.8666 - val_loss: 0.1917 - val_my_iou_metric: 0.7968
#
# Epoch 00136: my_iou_metric improved from 0.86611 to 0.86658, saving model to Unet_resnet_v5.model
# Epoch 137/200
#  - 89s - loss: 0.0267 - my_iou_metric: 0.8670 - val_loss: 0.2027 - val_my_iou_metric: 0.7846
#
# Epoch 00137: my_iou_metric improved from 0.86658 to 0.86703, saving model to Unet_resnet_v5.model
# Epoch 138/200
#  - 89s - loss: 0.0274 - my_iou_metric: 0.8649 - val_loss: 0.2080 - val_my_iou_metric: 0.7876
#
# Epoch 00138: my_iou_metric did not improve from 0.86703
# Epoch 139/200
#  - 89s - loss: 0.0267 - my_iou_metric: 0.8674 - val_loss: 0.2087 - val_my_iou_metric: 0.7899
#
# Epoch 00139: my_iou_metric improved from 0.86703 to 0.86738, saving model to Unet_resnet_v5.model
# Epoch 140/200
#  - 88s - loss: 0.0272 - my_iou_metric: 0.8671 - val_loss: 0.1977 - val_my_iou_metric: 0.7936
#
# Epoch 00140: my_iou_metric did not improve from 0.86738
# Epoch 141/200
#  - 89s - loss: 0.0277 - my_iou_metric: 0.8669 - val_loss: 0.2020 - val_my_iou_metric: 0.7974
#
# Epoch 00141: my_iou_metric did not improve from 0.86738
# Epoch 142/200
#  - 89s - loss: 0.0268 - my_iou_metric: 0.8652 - val_loss: 0.2018 - val_my_iou_metric: 0.7960
#
# Epoch 00142: my_iou_metric did not improve from 0.86738
# Epoch 143/200
#  - 88s - loss: 0.0262 - my_iou_metric: 0.8683 - val_loss: 0.2002 - val_my_iou_metric: 0.7980
#
# Epoch 00143: my_iou_metric improved from 0.86738 to 0.86831, saving model to Unet_resnet_v5.model
# Epoch 144/200
#  - 89s - loss: 0.0272 - my_iou_metric: 0.8684 - val_loss: 0.2071 - val_my_iou_metric: 0.7913
#
# Epoch 00144: my_iou_metric improved from 0.86831 to 0.86839, saving model to Unet_resnet_v5.model
# Epoch 145/200
#  - 89s - loss: 0.0263 - my_iou_metric: 0.8662 - val_loss: 0.2089 - val_my_iou_metric: 0.7939
#
# Epoch 00145: my_iou_metric did not improve from 0.86839
# Epoch 146/200
#  - 89s - loss: 0.0263 - my_iou_metric: 0.8662 - val_loss: 0.2069 - val_my_iou_metric: 0.7916
#
# Epoch 00146: my_iou_metric did not improve from 0.86839
# Epoch 147/200
#  - 88s - loss: 0.0264 - my_iou_metric: 0.8670 - val_loss: 0.2107 - val_my_iou_metric: 0.7850
#
# Epoch 00147: my_iou_metric did not improve from 0.86839
# Epoch 148/200
#  - 89s - loss: 0.0268 - my_iou_metric: 0.8656 - val_loss: 0.2022 - val_my_iou_metric: 0.7873
#
# Epoch 00148: my_iou_metric did not improve from 0.86839
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 0.0004665599903091788.
# Epoch 149/200
#  - 89s - loss: 0.0261 - my_iou_metric: 0.8704 - val_loss: 0.2035 - val_my_iou_metric: 0.7930
#
# Epoch 00149: my_iou_metric improved from 0.86839 to 0.87039, saving model to Unet_resnet_v5.model
# Epoch 150/200
#  - 88s - loss: 0.0263 - my_iou_metric: 0.8705 - val_loss: 0.1986 - val_my_iou_metric: 0.7975
#
# Epoch 00150: my_iou_metric improved from 0.87039 to 0.87055, saving model to Unet_resnet_v5.model
# Epoch 151/200
#  - 89s - loss: 0.0258 - my_iou_metric: 0.8664 - val_loss: 0.2006 - val_my_iou_metric: 0.7936
#
# Epoch 00151: my_iou_metric did not improve from 0.87055
# Epoch 152/200
#  - 89s - loss: 0.0255 - my_iou_metric: 0.8690 - val_loss: 0.2042 - val_my_iou_metric: 0.7987
#
# Epoch 00152: my_iou_metric did not improve from 0.87055
# Epoch 153/200
#  - 89s - loss: 0.0257 - my_iou_metric: 0.8680 - val_loss: 0.2061 - val_my_iou_metric: 0.7936
#
# Epoch 00153: my_iou_metric did not improve from 0.87055
# Epoch 154/200
#  - 88s - loss: 0.0258 - my_iou_metric: 0.8701 - val_loss: 0.2077 - val_my_iou_metric: 0.7941
#
# Epoch 00154: my_iou_metric did not improve from 0.87055
# Epoch 155/200
#  - 88s - loss: 0.0260 - my_iou_metric: 0.8706 - val_loss: 0.2134 - val_my_iou_metric: 0.7939
#
# Epoch 00155: my_iou_metric improved from 0.87055 to 0.87062, saving model to Unet_resnet_v5.model
#
# Epoch 00155: ReduceLROnPlateau reducing learning rate to 0.00027993599069304765.
# Epoch 156/200
#  - 89s - loss: 0.0255 - my_iou_metric: 0.8692 - val_loss: 0.2154 - val_my_iou_metric: 0.7932
#
# Epoch 00156: my_iou_metric did not improve from 0.87062
# Epoch 157/200
#  - 88s - loss: 0.0255 - my_iou_metric: 0.8685 - val_loss: 0.2165 - val_my_iou_metric: 0.7948
#
# Epoch 00157: my_iou_metric did not improve from 0.87062
# Epoch 158/200
#  - 89s - loss: 0.0253 - my_iou_metric: 0.8685 - val_loss: 0.2123 - val_my_iou_metric: 0.7950
#
# Epoch 00158: my_iou_metric did not improve from 0.87062
# Epoch 159/200
#  - 89s - loss: 0.0256 - my_iou_metric: 0.8697 - val_loss: 0.2115 - val_my_iou_metric: 0.7965
#
# Epoch 00159: my_iou_metric did not improve from 0.87062
# Epoch 160/200
#  - 88s - loss: 0.0251 - my_iou_metric: 0.8711 - val_loss: 0.2151 - val_my_iou_metric: 0.7934
#
# Epoch 00160: my_iou_metric improved from 0.87062 to 0.87111, saving model to Unet_resnet_v5.model
# Epoch 161/200
#  - 88s - loss: 0.0251 - my_iou_metric: 0.8690 - val_loss: 0.2119 - val_my_iou_metric: 0.7953
#
# Epoch 00161: my_iou_metric did not improve from 0.87111
# Epoch 162/200
#  - 89s - loss: 0.0256 - my_iou_metric: 0.8709 - val_loss: 0.2137 - val_my_iou_metric: 0.7947
#
# Epoch 00162: my_iou_metric did not improve from 0.87111
# Epoch 163/200
#  - 89s - loss: 0.0255 - my_iou_metric: 0.8694 - val_loss: 0.2149 - val_my_iou_metric: 0.7943
#
# Epoch 00163: my_iou_metric did not improve from 0.87111
# Epoch 164/200
#  - 88s - loss: 0.0257 - my_iou_metric: 0.8709 - val_loss: 0.2142 - val_my_iou_metric: 0.7924
#
# Epoch 00164: my_iou_metric did not improve from 0.87111
# Epoch 165/200
#  - 89s - loss: 0.0257 - my_iou_metric: 0.8695 - val_loss: 0.2146 - val_my_iou_metric: 0.7966
#
# Epoch 00165: my_iou_metric did not improve from 0.87111
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 0.00016796158743090928.
# Epoch 166/200
#  - 89s - loss: 0.0252 - my_iou_metric: 0.8710 - val_loss: 0.2171 - val_my_iou_metric: 0.7941
#
# Epoch 00166: my_iou_metric did not improve from 0.87111
# Epoch 167/200
#  - 89s - loss: 0.0252 - my_iou_metric: 0.8715 - val_loss: 0.2162 - val_my_iou_metric: 0.7944
#
# Epoch 00167: my_iou_metric improved from 0.87111 to 0.87153, saving model to Unet_resnet_v5.model
# Epoch 168/200
#  - 88s - loss: 0.0252 - my_iou_metric: 0.8698 - val_loss: 0.2158 - val_my_iou_metric: 0.7952
#
# Epoch 00168: my_iou_metric did not improve from 0.87153
# Epoch 169/200
#  - 89s - loss: 0.0251 - my_iou_metric: 0.8703 - val_loss: 0.2192 - val_my_iou_metric: 0.7941
#
# Epoch 00169: my_iou_metric did not improve from 0.87153
# Epoch 170/200
#  - 89s - loss: 0.0262 - my_iou_metric: 0.8708 - val_loss: 0.2136 - val_my_iou_metric: 0.7935
#
# Epoch 00170: my_iou_metric did not improve from 0.87153
# Epoch 171/200
#  - 88s - loss: 0.0250 - my_iou_metric: 0.8717 - val_loss: 0.2151 - val_my_iou_metric: 0.7944
#
# Epoch 00171: my_iou_metric improved from 0.87153 to 0.87170, saving model to Unet_resnet_v5.model
# Epoch 172/200
#  - 89s - loss: 0.0254 - my_iou_metric: 0.8696 - val_loss: 0.2184 - val_my_iou_metric: 0.7883
#
# Epoch 00172: my_iou_metric did not improve from 0.87170
# Epoch 173/200
#  - 89s - loss: 0.0256 - my_iou_metric: 0.8700 - val_loss: 0.2148 - val_my_iou_metric: 0.7915
#
# Epoch 00173: my_iou_metric did not improve from 0.87170
# Epoch 174/200
#  - 89s - loss: 0.0253 - my_iou_metric: 0.8689 - val_loss: 0.2152 - val_my_iou_metric: 0.7929
#
# Epoch 00174: my_iou_metric did not improve from 0.87170
# Epoch 175/200
#  - 88s - loss: 0.0248 - my_iou_metric: 0.8726 - val_loss: 0.2158 - val_my_iou_metric: 0.7936
#
# Epoch 00175: my_iou_metric improved from 0.87170 to 0.87259, saving model to Unet_resnet_v5.model
# Epoch 176/200
#  - 89s - loss: 0.0245 - my_iou_metric: 0.8703 - val_loss: 0.2200 - val_my_iou_metric: 0.7936
#
# Epoch 00176: my_iou_metric did not improve from 0.87259
# Epoch 177/200
#  - 89s - loss: 0.0250 - my_iou_metric: 0.8730 - val_loss: 0.2212 - val_my_iou_metric: 0.7963
# Epoch 00177: my_iou_metric improved from 0.87259 to 0.87297, saving model to Unet_resnet_v5.model
# Epoch 178/200
#  - 88s - loss: 0.0259 - my_iou_metric: 0.8700 - val_loss: 0.2158 - val_my_iou_metric: 0.7952
#
# Epoch 00178: my_iou_metric did not improve from 0.87297
# Epoch 179/200
#  - 89s - loss: 0.0246 - my_iou_metric: 0.8722 - val_loss: 0.2171 - val_my_iou_metric: 0.7941
#
# Epoch 00179: my_iou_metric did not improve from 0.87297
# Epoch 180/200
#  - 89s - loss: 0.0244 - my_iou_metric: 0.8742 - val_loss: 0.2189 - val_my_iou_metric: 0.7947
#
# Epoch 00180: my_iou_metric improved from 0.87297 to 0.87419, saving model to Unet_resnet_v5.model
# Epoch 181/200
#  - 89s - loss: 0.0272 - my_iou_metric: 0.8727 - val_loss: 0.2162 - val_my_iou_metric: 0.7927
#
# Epoch 00181: my_iou_metric did not improve from 0.87419
# Epoch 182/200
#  - 88s - loss: 0.0249 - my_iou_metric: 0.8702 - val_loss: 0.2197 - val_my_iou_metric: 0.7939
#
# Epoch 00182: my_iou_metric did not improve from 0.87419
# Epoch 183/200
#  - 89s - loss: 0.0246 - my_iou_metric: 0.8722 - val_loss: 0.2219 - val_my_iou_metric: 0.7961
#
# Epoch 00183: my_iou_metric did not improve from 0.87419
# Epoch 184/200
#  - 89s - loss: 0.0247 - my_iou_metric: 0.8742 - val_loss: 0.2223 - val_my_iou_metric: 0.7955
#
# Epoch 00184: my_iou_metric improved from 0.87419 to 0.87423, saving model to Unet_resnet_v5.model
# Epoch 185/200
#  - 88s - loss: 0.0247 - my_iou_metric: 0.8718 - val_loss: 0.2200 - val_my_iou_metric: 0.7956
#
# Epoch 00185: my_iou_metric did not improve from 0.87423
#
# Epoch 00185: ReduceLROnPlateau reducing learning rate to 0.00010077694896608591.
# Epoch 186/200
#  - 89s - loss: 0.0251 - my_iou_metric: 0.8690 - val_loss: 0.2199 - val_my_iou_metric: 0.7944
#
# Epoch 00186: my_iou_metric did not improve from 0.87423
# Epoch 187/200
#  - 89s - loss: 0.0249 - my_iou_metric: 0.8705 - val_loss: 0.2171 - val_my_iou_metric: 0.7983
#
# Epoch 00187: my_iou_metric did not improve from 0.87423
# Epoch 188/200
#  - 89s - loss: 0.0247 - my_iou_metric: 0.8706 - val_loss: 0.2196 - val_my_iou_metric: 0.7975
#
# Epoch 00188: my_iou_metric did not improve from 0.87423
# Epoch 189/200
#  - 88s - loss: 0.0243 - my_iou_metric: 0.8728 - val_loss: 0.2193 - val_my_iou_metric: 0.7945
#
# Epoch 00189: my_iou_metric did not improve from 0.87423
# Epoch 190/200
#  - 89s - loss: 0.0246 - my_iou_metric: 0.8699 - val_loss: 0.2202 - val_my_iou_metric: 0.7943
#
# Epoch 00190: my_iou_metric did not improve from 0.87423
#
# Epoch 00190: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 191/200
#  - 88s - loss: 0.0250 - my_iou_metric: 0.8712 - val_loss: 0.2180 - val_my_iou_metric: 0.7965
#
# Epoch 00191: my_iou_metric did not improve from 0.87423
# Epoch 192/200
#  - 88s - loss: 0.0250 - my_iou_metric: 0.8709 - val_loss: 0.2164 - val_my_iou_metric: 0.7955
#
# Epoch 00192: my_iou_metric did not improve from 0.87423
# Epoch 193/200
#  - 88s - loss: 0.0247 - my_iou_metric: 0.8728 - val_loss: 0.2198 - val_my_iou_metric: 0.7935
#
# Epoch 00193: my_iou_metric did not improve from 0.87423
# Epoch 194/200
#  - 89s - loss: 0.0245 - my_iou_metric: 0.8719 - val_loss: 0.2196 - val_my_iou_metric: 0.7953
#
# Epoch 00194: my_iou_metric did not improve from 0.87423
# Epoch 195/200
#  - 89s - loss: 0.0247 - my_iou_metric: 0.8734 - val_loss: 0.2183 - val_my_iou_metric: 0.7965
#
# Epoch 00195: my_iou_metric did not improve from 0.87423
# Epoch 196/200
#  - 88s - loss: 0.0245 - my_iou_metric: 0.8736 - val_loss: 0.2181 - val_my_iou_metric: 0.7970
#
# Epoch 00196: my_iou_metric did not improve from 0.87423
# Epoch 197/200
#  - 89s - loss: 0.0247 - my_iou_metric: 0.8689 - val_loss: 0.2144 - val_my_iou_metric: 0.7950
#
# Epoch 00197: my_iou_metric did not improve from 0.87423
# Epoch 198/200
#  - 89s - loss: 0.0247 - my_iou_metric: 0.8718 - val_loss: 0.2163 - val_my_iou_metric: 0.7969
#
# Epoch 00198: my_iou_metric did not improve from 0.87423
# Epoch 199/200
#  - 88s - loss: 0.0247 - my_iou_metric: 0.8716 - val_loss: 0.2178 - val_my_iou_metric: 0.7959
#
# Epoch 00199: my_iou_metric did not improve from 0.87423
# Epoch 200/200
#  - 89s - loss: 0.0244 - my_iou_metric: 0.8728 - val_loss: 0.2185 - val_my_iou_metric: 0.7956
#
# Epoch 00200: my_iou_metric did not improve from 0.87423

# %%
model1 = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.6, patience=5, min_lr=0.0001, verbose=1)
epochs = 200
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr,early_stopping], 
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/200
#  - 210s - loss: 0.3243 - my_iou_metric_2: 0.8393 - val_loss: 0.5345 - val_my_iou_metric_2: 0.7658
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.76575, saving model to Unet_resnet_v5.model
# Epoch 2/200
#  - 195s - loss: 0.2801 - my_iou_metric_2: 0.8445 - val_loss: 0.5329 - val_my_iou_metric_2: 0.7796
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.76575 to 0.77963, saving model to Unet_resnet_v5.model
# Epoch 3/200
#  - 195s - loss: 0.2755 - my_iou_metric_2: 0.8438 - val_loss: 0.4421 - val_my_iou_metric_2: 0.7880
#
# Epoch 00003: val_my_iou_metric_2 improved from 0.77963 to 0.78800, saving model to Unet_resnet_v5.model
# Epoch 4/200
#  - 195s - loss: 0.2837 - my_iou_metric_2: 0.8384 - val_loss: 0.4478 - val_my_iou_metric_2: 0.7844
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.78800
# Epoch 5/200
#  - 195s - loss: 0.2788 - my_iou_metric_2: 0.8375 - val_loss: 0.4649 - val_my_iou_metric_2: 0.7644
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.78800
# Epoch 6/200
#  - 195s - loss: 0.2815 - my_iou_metric_2: 0.8370 - val_loss: 0.4343 - val_my_iou_metric_2: 0.7669
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.78800
# Epoch 7/200
#  - 195s - loss: 0.2862 - my_iou_metric_2: 0.8330 - val_loss: 0.4456 - val_my_iou_metric_2: 0.7645
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.78800
# Epoch 8/200
#  - 195s - loss: 0.2974 - my_iou_metric_2: 0.8237 - val_loss: 0.4667 - val_my_iou_metric_2: 0.7706
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.78800
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# Epoch 9/200
#  - 195s - loss: 0.2638 - my_iou_metric_2: 0.8400 - val_loss: 0.3811 - val_my_iou_metric_2: 0.7901
#
# Epoch 00009: val_my_iou_metric_2 improved from 0.78800 to 0.79013, saving model to Unet_resnet_v5.model
# Epoch 10/200
#  - 195s - loss: 0.2471 - my_iou_metric_2: 0.8493 - val_loss: 0.3924 - val_my_iou_metric_2: 0.7831
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.79013
# Epoch 11/200
#  - 194s - loss: 0.2444 - my_iou_metric_2: 0.8507 - val_loss: 0.3906 - val_my_iou_metric_2: 0.7900
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.79013
# Epoch 12/200
#  - 194s - loss: 0.2492 - my_iou_metric_2: 0.8469 - val_loss: 0.4039 - val_my_iou_metric_2: 0.7791
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.79013
# Epoch 13/200
#  - 195s - loss: 0.2335 - my_iou_metric_2: 0.8545 - val_loss: 0.3770 - val_my_iou_metric_2: 0.7935
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.79013 to 0.79350, saving model to Unet_resnet_v5.model
# Epoch 14/200
#  - 195s - loss: 0.2451 - my_iou_metric_2: 0.8489 - val_loss: 0.4092 - val_my_iou_metric_2: 0.7804
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.79350
# Epoch 15/200
#  - 194s - loss: 0.2561 - my_iou_metric_2: 0.8437 - val_loss: 0.4025 - val_my_iou_metric_2: 0.7784
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79350
# Epoch 16/200
#  - 194s - loss: 0.2570 - my_iou_metric_2: 0.8432 - val_loss: 0.3758 - val_my_iou_metric_2: 0.7935
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.79350
# Epoch 17/200
#  - 194s - loss: 0.2538 - my_iou_metric_2: 0.8444 - val_loss: 0.3914 - val_my_iou_metric_2: 0.7870
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.79350
# Epoch 18/200
#  - 194s - loss: 0.2489 - my_iou_metric_2: 0.8472 - val_loss: 0.3716 - val_my_iou_metric_2: 0.7939
#
# Epoch 00018: val_my_iou_metric_2 improved from 0.79350 to 0.79387, saving model to Unet_resnet_v5.model
# Epoch 19/200
#  - 194s - loss: 0.2317 - my_iou_metric_2: 0.8559 - val_loss: 0.3653 - val_my_iou_metric_2: 0.7930
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 20/200
#  - 194s - loss: 0.2331 - my_iou_metric_2: 0.8552 - val_loss: 0.3918 - val_my_iou_metric_2: 0.7839
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 21/200
#  - 194s - loss: 0.2478 - my_iou_metric_2: 0.8458 - val_loss: 0.3734 - val_my_iou_metric_2: 0.7935
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 22/200
#  - 194s - loss: 0.2395 - my_iou_metric_2: 0.8515 - val_loss: 0.3744 - val_my_iou_metric_2: 0.7895
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.79387
# Epoch 23/200
#  - 194s - loss: 0.2347 - my_iou_metric_2: 0.8543 - val_loss: 0.3691 - val_my_iou_metric_2: 0.7926
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.79387
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# Epoch 24/200
#  - 195s - loss: 0.2228 - my_iou_metric_2: 0.8596 - val_loss: 0.3566 - val_my_iou_metric_2: 0.7986
#
# Epoch 00024: val_my_iou_metric_2 improved from 0.79387 to 0.79862, saving model to Unet_resnet_v5.model
# Epoch 25/200
#  - 194s - loss: 0.2116 - my_iou_metric_2: 0.8650 - val_loss: 0.3598 - val_my_iou_metric_2: 0.7989
#
# Epoch 00025: val_my_iou_metric_2 improved from 0.79862 to 0.79888, saving model to Unet_resnet_v5.model
# Epoch 26/200
#  - 194s - loss: 0.2157 - my_iou_metric_2: 0.8638 - val_loss: 0.3590 - val_my_iou_metric_2: 0.7958
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.79888
# Epoch 27/200
#  - 194s - loss: 0.2139 - my_iou_metric_2: 0.8653 - val_loss: 0.3514 - val_my_iou_metric_2: 0.8004
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.79888 to 0.80037, saving model to Unet_resnet_v5.model
# Epoch 28/200
#  - 194s - loss: 0.2135 - my_iou_metric_2: 0.8666 - val_loss: 0.3576 - val_my_iou_metric_2: 0.7969
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.80037
# Epoch 29/200
#  - 195s - loss: 0.2119 - my_iou_metric_2: 0.8673 - val_loss: 0.3610 - val_my_iou_metric_2: 0.7920
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.80037
# Epoch 30/200
#  - 195s - loss: 0.2112 - my_iou_metric_2: 0.8661 - val_loss: 0.3728 - val_my_iou_metric_2: 0.7856
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.80037
# Epoch 31/200
#  - 195s - loss: 0.2103 - my_iou_metric_2: 0.8673 - val_loss: 0.3564 - val_my_iou_metric_2: 0.8015
#
# Epoch 00031: val_my_iou_metric_2 improved from 0.80037 to 0.80150, saving model to Unet_resnet_v5.model
# Epoch 32/200
#  - 195s - loss: 0.2065 - my_iou_metric_2: 0.8685 - val_loss: 0.3504 - val_my_iou_metric_2: 0.7974
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.80150
# Epoch 33/200
#  - 195s - loss: 0.2084 - my_iou_metric_2: 0.8678 - val_loss: 0.3512 - val_my_iou_metric_2: 0.8006
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.80150
# Epoch 34/200
#  - 195s - loss: 0.2106 - my_iou_metric_2: 0.8668 - val_loss: 0.3540 - val_my_iou_metric_2: 0.8017
#
# Epoch 00034: val_my_iou_metric_2 improved from 0.80150 to 0.80175, saving model to Unet_resnet_v5.model
# Epoch 35/200
#  - 194s - loss: 0.2093 - my_iou_metric_2: 0.8667 - val_loss: 0.3510 - val_my_iou_metric_2: 0.7966
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 36/200
#  - 194s - loss: 0.2138 - my_iou_metric_2: 0.8646 - val_loss: 0.3707 - val_my_iou_metric_2: 0.7901
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 37/200
#  - 195s - loss: 0.2051 - my_iou_metric_2: 0.8701 - val_loss: 0.3600 - val_my_iou_metric_2: 0.7955
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 38/200
#  - 195s - loss: 0.2055 - my_iou_metric_2: 0.8693 - val_loss: 0.3665 - val_my_iou_metric_2: 0.7951
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 39/200
#  - 195s - loss: 0.2068 - my_iou_metric_2: 0.8700 - val_loss: 0.3609 - val_my_iou_metric_2: 0.7953
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.80175
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# Epoch 40/200
#  - 195s - loss: 0.2000 - my_iou_metric_2: 0.8725 - val_loss: 0.3552 - val_my_iou_metric_2: 0.8008
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 41/200
#  - 195s - loss: 0.1969 - my_iou_metric_2: 0.8756 - val_loss: 0.3587 - val_my_iou_metric_2: 0.7969
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 42/200
#  - 195s - loss: 0.1931 - my_iou_metric_2: 0.8772 - val_loss: 0.3602 - val_my_iou_metric_2: 0.7946
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 43/200
#  - 195s - loss: 0.1885 - my_iou_metric_2: 0.8789 - val_loss: 0.3604 - val_my_iou_metric_2: 0.7993
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.80175
# Epoch 44/200
#  - 195s - loss: 0.1839 - my_iou_metric_2: 0.8816 - val_loss: 0.3588 - val_my_iou_metric_2: 0.7955
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.80175
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# Epoch 45/200
#  - 194s - loss: 0.1845 - my_iou_metric_2: 0.8814 - val_loss: 0.3518 - val_my_iou_metric_2: 0.8039
#
# Epoch 00045: val_my_iou_metric_2 improved from 0.80175 to 0.80387, saving model to Unet_resnet_v5.model
# Epoch 46/200
#  - 195s - loss: 0.1841 - my_iou_metric_2: 0.8816 - val_loss: 0.3457 - val_my_iou_metric_2: 0.8072
#
# Epoch 00046: val_my_iou_metric_2 improved from 0.80387 to 0.80725, saving model to Unet_resnet_v5.model
# Epoch 47/200
#  - 195s - loss: 0.1830 - my_iou_metric_2: 0.8839 - val_loss: 0.3554 - val_my_iou_metric_2: 0.8008
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 48/200
#  - 196s - loss: 0.1817 - my_iou_metric_2: 0.8836 - val_loss: 0.3474 - val_my_iou_metric_2: 0.8029
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 49/200
#  - 195s - loss: 0.1823 - my_iou_metric_2: 0.8840 - val_loss: 0.3618 - val_my_iou_metric_2: 0.7956
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 50/200
#  - 195s - loss: 0.1821 - my_iou_metric_2: 0.8837 - val_loss: 0.3467 - val_my_iou_metric_2: 0.8012
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 51/200
#  - 195s - loss: 0.1805 - my_iou_metric_2: 0.8837 - val_loss: 0.3687 - val_my_iou_metric_2: 0.7921
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.80725
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0007775999838486314.
# Epoch 52/200
#  - 195s - loss: 0.1748 - my_iou_metric_2: 0.8874 - val_loss: 0.3545 - val_my_iou_metric_2: 0.7972
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 53/200
#  - 196s - loss: 0.1785 - my_iou_metric_2: 0.8852 - val_loss: 0.3676 - val_my_iou_metric_2: 0.7920
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 54/200
#  - 195s - loss: 0.1782 - my_iou_metric_2: 0.8861 - val_loss: 0.3661 - val_my_iou_metric_2: 0.7911
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 55/200
#  - 195s - loss: 0.1773 - my_iou_metric_2: 0.8857 - val_loss: 0.3645 - val_my_iou_metric_2: 0.7935
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 56/200
#  - 194s - loss: 0.1746 - my_iou_metric_2: 0.8878 - val_loss: 0.3567 - val_my_iou_metric_2: 0.7970
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.80725
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0004665599903091788.
# Epoch 57/200
#  - 193s - loss: 0.1728 - my_iou_metric_2: 0.8883 - val_loss: 0.3579 - val_my_iou_metric_2: 0.7972
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 58/200
#  - 195s - loss: 0.1727 - my_iou_metric_2: 0.8887 - val_loss: 0.3507 - val_my_iou_metric_2: 0.8010
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 59/200
#  - 196s - loss: 0.1740 - my_iou_metric_2: 0.8880 - val_loss: 0.3563 - val_my_iou_metric_2: 0.7984
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 60/200
#  - 195s - loss: 0.1742 - my_iou_metric_2: 0.8876 - val_loss: 0.3527 - val_my_iou_metric_2: 0.7977
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 61/200
#  - 196s - loss: 0.1719 - my_iou_metric_2: 0.8900 - val_loss: 0.3515 - val_my_iou_metric_2: 0.7991
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.80725
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.00027993599069304765.
# Epoch 62/200
#  - 195s - loss: 0.1722 - my_iou_metric_2: 0.8887 - val_loss: 0.3514 - val_my_iou_metric_2: 0.8004
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 63/200
#  - 196s - loss: 0.1718 - my_iou_metric_2: 0.8896 - val_loss: 0.3481 - val_my_iou_metric_2: 0.8044
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 64/200
#  - 196s - loss: 0.1697 - my_iou_metric_2: 0.8909 - val_loss: 0.3468 - val_my_iou_metric_2: 0.8037
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 65/200
#  - 195s - loss: 0.1704 - my_iou_metric_2: 0.8899 - val_loss: 0.3500 - val_my_iou_metric_2: 0.8024
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.80725
# Epoch 66/200
#  - 195s - loss: 0.1715 - my_iou_metric_2: 0.8897 - val_loss: 0.3513 - val_my_iou_metric_2: 0.8003
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.80725
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.00016796158743090928.
# Epoch 00066: early stopping

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
model = load_model(save_model_name,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
preds_valid = predict_result(model,x_valid,img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))
#     temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))
    #print(temp1)
    intersection = temp1[0]
    #print("temp2 = ",temp1[1])
    #print(intersection.shape)
   # print(intersection)
    # Compute areas (needed for finding the union between all objects)
    #print(np.histogram(labels, bins = true_objects))
    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    #print("area_true = ",area_true)
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
  
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.798625 0.8      0.801875 0.803    0.803    0.803625 0.80325  0.803625
#  0.803375 0.80425  0.804125 0.80575  0.805    0.8045   0.80575  0.802625
#  0.80075  0.8005   0.800125 0.80125  0.800875 0.800875 0.799625 0.79875
#  0.798125 0.797    0.796    0.7955   0.79775  0.79625  0.7955  ]

# %%
# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array([(np.array(load_img("data/salt/test/images/{}.png".format(idx), 
                                      grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/szelee/anaconda3/envs/tf/lib/python3.6/site-packages/keras_preprocessing/image.py:489: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, 
             idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 6.6159584522247314 s

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submission_file)

# %%
t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# Kernel run time = 8.738907588919004 hours
