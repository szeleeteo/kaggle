# %% [markdown]
# # Import libraries

# %%
import os
import sys
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

import cv2

from tqdm import tqdm_notebook #, tnrange
# from skimage.io import imread, imshow #, concatenate_images
# from skimage.transform import resize
# from skimage.morphology import label

import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img#,save_img
from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time
t_start = time.time()

# %% [markdown]
# # Clean data

# %%
DATA_DIR = 'data/salt/'

# %%
version = 1
basic_name = f'unet_v1_{version}'
save_model_name = basic_name + 'A.model'
save_model_nameB = basic_name + 'B.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(save_model_nameB)
print(submission_file)
# Out:
# unet_v1_1A.model
# unet_v1_1B.model
# unet_v1_1.csv

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True, anti_aliasing=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True, anti_aliasing=True)

# %% [markdown]
# # Stratify data by depth

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv(f"{DATA_DIR}train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv(f"{DATA_DIR}depths.csv", index_col="id")
train_df = train_df.join(depths_df)

test_df = depths_df[~depths_df.index.isin(train_df.index)]

# %%
train_data_mean = 120.34612148318793
train_data_std = 41.06966522016206

# %%
img_list = []
mask_list = []

for idx in tqdm_notebook(train_df.index):
    img = load_img(f"{DATA_DIR}train/images/{idx}.png", grayscale=True)
    mask = load_img(f"{DATA_DIR}train/masks/{idx}.png", grayscale=True)
    
    img_list.append(((np.array(img)-train_data_mean)/train_data_std))
    mask_list.append(np.array(mask)/255)
    
train_df['images'] = img_list
train_df['masks'] = mask_list
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
np.array(img_list).mean(), np.array(img_list).std()
# Out:
# (-1.2913893070279636e-16, 0.9999999999999998)

# %%
# one-liner version, with division by 255
# train_df["images"] = [np.array(load_img(f"data/salt/train/images/{idx}.png", grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# train_df["masks"] = [np.array(load_img("data/salt/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

train_df["coverage_class"] = train_df.coverage.apply(lambda val: np.int(np.ceil(val*10)))

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5, 0, 'Coverage class')

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5, 0, 'Coverage class')

# %%
# Plotting the depth distributions¶

sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5, 1.0, 'Depth distribution')

# %%
train_df.index[0]
# Out:
# '575d24d81d'

# %%
def plot2x2Array(image, mask):
    f, axarr = plt.subplots(1,2)
    axarr[0].imshow(image, cmap="gray")
    axarr[1].imshow(mask, cmap="gray")
    axarr[0].grid(False)
    axarr[1].grid(False)
    axarr[0].set_title('Image')
    axarr[1].set_title('Mask')
    
for i, idx in enumerate(train_df.index[:10]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    plot2x2Array(img, mask)

# %%
max_images = 60
grid_width = 10
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width*1.5, grid_height*1.5))

for i, idx in enumerate(train_df.index[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
plt.suptitle("Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5, 0.98, 'Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Split data
#
# stratified by salt coverage

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, 
    stratify=train_df.coverage_class, 
    random_state=1234)

# %% [markdown]
# # Augment Data

# %%
print(x_train.shape)
print(y_valid.shape)
# Out:
# (3200, 101, 101, 1)
# (800, 101, 101, 1)

# %%
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

# %%
print(x_train.shape)
print(y_valid.shape)
# Out:
# (6400, 101, 101, 1)
# (800, 101, 101, 1)

# %% [markdown]
# To be improved with Albumentations
# https://github.com/albu/albumentations/blob/master/notebooks/example_kaggle_salt.ipynb

# %% [markdown]
# # Create Metrics

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        #loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %% [markdown]
# # Define blocks and model

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.4):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %% [markdown]
# # Build model and set hyperparameters

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16, 0.5)

model1 = Model(input_layer, output_layer)

# c = optimizers.Adam(lr=0.01)
c = optimizers.RMSprop(lr=0.01)

model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])

#model1.summary()

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric', mode='max', patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name, monitor='val_my_iou_metric', mode='max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric', mode='max', factor=0.6, patience=10, min_lr=0.0001, verbose=1)

epochs = 300
batch_size = 32

# %% [markdown]
# # Train

# %%
# %%time
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping, model_checkpoint, reduce_lr], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/300
# 6400/6400 [==============================] - 94s 15ms/step - loss: 0.4420 - my_iou_metric: 0.3573 - val_loss: 0.5256 - val_my_iou_metric: 0.3315
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.33150, saving model to unet_v1_1A.model
# Epoch 2/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.3476 - my_iou_metric: 0.5117 - val_loss: 0.4026 - val_my_iou_metric: 0.2114
#
# Epoch 00002: val_my_iou_metric did not improve from 0.33150
# Epoch 3/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.2983 - my_iou_metric: 0.5377 - val_loss: 0.3446 - val_my_iou_metric: 0.5341
#
# Epoch 00003: val_my_iou_metric improved from 0.33150 to 0.53412, saving model to unet_v1_1A.model
# Epoch 4/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2631 - my_iou_metric: 0.5685 - val_loss: 0.3438 - val_my_iou_metric: 0.3514
#
# Epoch 00004: val_my_iou_metric did not improve from 0.53412
# Epoch 5/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.2399 - my_iou_metric: 0.5782 - val_loss: 0.2809 - val_my_iou_metric: 0.6128
#
# Epoch 00005: val_my_iou_metric improved from 0.53412 to 0.61275, saving model to unet_v1_1A.model
# Epoch 6/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.2294 - my_iou_metric: 0.5845 - val_loss: 0.2451 - val_my_iou_metric: 0.5651
#
# Epoch 00006: val_my_iou_metric did not improve from 0.61275
# Epoch 7/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.2121 - my_iou_metric: 0.6097 - val_loss: 0.2754 - val_my_iou_metric: 0.6109
#
# Epoch 00007: val_my_iou_metric did not improve from 0.61275
# Epoch 8/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.2049 - my_iou_metric: 0.6242 - val_loss: 0.1888 - val_my_iou_metric: 0.6637
#
# Epoch 00008: val_my_iou_metric improved from 0.61275 to 0.66375, saving model to unet_v1_1A.model
# Epoch 9/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1973 - my_iou_metric: 0.6281 - val_loss: 0.2033 - val_my_iou_metric: 0.6289
#
# Epoch 00009: val_my_iou_metric did not improve from 0.66375
# Epoch 10/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1897 - my_iou_metric: 0.6443 - val_loss: 0.1871 - val_my_iou_metric: 0.6949
#
# Epoch 00010: val_my_iou_metric improved from 0.66375 to 0.69488, saving model to unet_v1_1A.model
# Epoch 11/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1816 - my_iou_metric: 0.6547 - val_loss: 0.1881 - val_my_iou_metric: 0.6581
#
# Epoch 00011: val_my_iou_metric did not improve from 0.69488
# Epoch 12/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1770 - my_iou_metric: 0.6668 - val_loss: 0.1994 - val_my_iou_metric: 0.6876
#
# Epoch 00012: val_my_iou_metric did not improve from 0.69488
# Epoch 13/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1698 - my_iou_metric: 0.6692 - val_loss: 0.1856 - val_my_iou_metric: 0.6914
#
# Epoch 00013: val_my_iou_metric did not improve from 0.69488
# Epoch 14/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1667 - my_iou_metric: 0.6782 - val_loss: 0.3323 - val_my_iou_metric: 0.5430
#
# Epoch 00014: val_my_iou_metric did not improve from 0.69488
# Epoch 15/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1616 - my_iou_metric: 0.6853 - val_loss: 0.1804 - val_my_iou_metric: 0.7105
#
# Epoch 00015: val_my_iou_metric improved from 0.69488 to 0.71050, saving model to unet_v1_1A.model
# Epoch 16/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1545 - my_iou_metric: 0.6938 - val_loss: 0.1885 - val_my_iou_metric: 0.7250
#
# Epoch 00016: val_my_iou_metric improved from 0.71050 to 0.72500, saving model to unet_v1_1A.model
# Epoch 17/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1543 - my_iou_metric: 0.6958 - val_loss: 0.1539 - val_my_iou_metric: 0.7324
#
# Epoch 00017: val_my_iou_metric improved from 0.72500 to 0.73238, saving model to unet_v1_1A.model
# Epoch 18/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1504 - my_iou_metric: 0.6977 - val_loss: 0.1712 - val_my_iou_metric: 0.7099
#
# Epoch 00018: val_my_iou_metric did not improve from 0.73238
# Epoch 19/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1510 - my_iou_metric: 0.6989 - val_loss: 0.1605 - val_my_iou_metric: 0.7069
#
# Epoch 00019: val_my_iou_metric did not improve from 0.73238
# Epoch 20/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1500 - my_iou_metric: 0.6993 - val_loss: 0.1820 - val_my_iou_metric: 0.7131
#
# Epoch 00020: val_my_iou_metric did not improve from 0.73238
# Epoch 21/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1428 - my_iou_metric: 0.7077 - val_loss: 0.1628 - val_my_iou_metric: 0.7219
#
# Epoch 00021: val_my_iou_metric did not improve from 0.73238
# Epoch 22/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1398 - my_iou_metric: 0.7158 - val_loss: 0.1738 - val_my_iou_metric: 0.7235
#
# Epoch 00022: val_my_iou_metric did not improve from 0.73238
# Epoch 23/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1386 - my_iou_metric: 0.7256 - val_loss: 0.1833 - val_my_iou_metric: 0.7143
#
# Epoch 00023: val_my_iou_metric did not improve from 0.73238
# Epoch 24/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1388 - my_iou_metric: 0.7175 - val_loss: 0.1605 - val_my_iou_metric: 0.7223
#
# Epoch 00024: val_my_iou_metric did not improve from 0.73238
# Epoch 25/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1340 - my_iou_metric: 0.7277 - val_loss: 0.1660 - val_my_iou_metric: 0.7090
#
# Epoch 00025: val_my_iou_metric did not improve from 0.73238
# Epoch 26/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1362 - my_iou_metric: 0.7234 - val_loss: 0.1509 - val_my_iou_metric: 0.7106
#
# Epoch 00026: val_my_iou_metric did not improve from 0.73238
# Epoch 27/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1312 - my_iou_metric: 0.7314 - val_loss: 0.1455 - val_my_iou_metric: 0.7321
#
# Epoch 00027: val_my_iou_metric did not improve from 0.73238
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# Epoch 28/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1210 - my_iou_metric: 0.7414 - val_loss: 0.1409 - val_my_iou_metric: 0.7536
#
# Epoch 00028: val_my_iou_metric improved from 0.73238 to 0.75362, saving model to unet_v1_1A.model
# Epoch 29/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1128 - my_iou_metric: 0.7515 - val_loss: 0.1564 - val_my_iou_metric: 0.7386
#
# Epoch 00029: val_my_iou_metric did not improve from 0.75362
# Epoch 30/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1135 - my_iou_metric: 0.7469 - val_loss: 0.1626 - val_my_iou_metric: 0.7519
#
# Epoch 00030: val_my_iou_metric did not improve from 0.75362
# Epoch 31/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1149 - my_iou_metric: 0.7492 - val_loss: 0.1572 - val_my_iou_metric: 0.7450
#
# Epoch 00031: val_my_iou_metric did not improve from 0.75362
# Epoch 32/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1119 - my_iou_metric: 0.7499 - val_loss: 0.1464 - val_my_iou_metric: 0.7580
#
# Epoch 00032: val_my_iou_metric improved from 0.75362 to 0.75800, saving model to unet_v1_1A.model
# Epoch 33/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1098 - my_iou_metric: 0.7553 - val_loss: 0.1409 - val_my_iou_metric: 0.7611
#
# Epoch 00033: val_my_iou_metric improved from 0.75800 to 0.76112, saving model to unet_v1_1A.model
# Epoch 34/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1118 - my_iou_metric: 0.7551 - val_loss: 0.1577 - val_my_iou_metric: 0.7418
#
# Epoch 00034: val_my_iou_metric did not improve from 0.76112
# Epoch 35/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1070 - my_iou_metric: 0.7555 - val_loss: 0.1574 - val_my_iou_metric: 0.7527
#
# Epoch 00035: val_my_iou_metric did not improve from 0.76112
# Epoch 36/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1096 - my_iou_metric: 0.7535 - val_loss: 0.1434 - val_my_iou_metric: 0.7596
#
# Epoch 00036: val_my_iou_metric did not improve from 0.76112
# Epoch 37/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1031 - my_iou_metric: 0.7597 - val_loss: 0.1611 - val_my_iou_metric: 0.7616
#
# Epoch 00037: val_my_iou_metric improved from 0.76112 to 0.76162, saving model to unet_v1_1A.model
# Epoch 38/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1047 - my_iou_metric: 0.7608 - val_loss: 0.1609 - val_my_iou_metric: 0.7576
#
# Epoch 00038: val_my_iou_metric did not improve from 0.76162
# Epoch 39/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.1034 - my_iou_metric: 0.7585 - val_loss: 0.1479 - val_my_iou_metric: 0.7529
#
# Epoch 00039: val_my_iou_metric did not improve from 0.76162
# Epoch 40/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1034 - my_iou_metric: 0.7563 - val_loss: 0.1630 - val_my_iou_metric: 0.7620
#
# Epoch 00040: val_my_iou_metric improved from 0.76162 to 0.76200, saving model to unet_v1_1A.model
# Epoch 41/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1009 - my_iou_metric: 0.7615 - val_loss: 0.1531 - val_my_iou_metric: 0.7652
#
# Epoch 00041: val_my_iou_metric improved from 0.76200 to 0.76525, saving model to unet_v1_1A.model
# Epoch 42/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.1016 - my_iou_metric: 0.7626 - val_loss: 0.1512 - val_my_iou_metric: 0.7559
#
# Epoch 00042: val_my_iou_metric did not improve from 0.76525
# Epoch 43/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0980 - my_iou_metric: 0.7672 - val_loss: 0.1677 - val_my_iou_metric: 0.7359
#
# Epoch 00043: val_my_iou_metric did not improve from 0.76525
# Epoch 44/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0998 - my_iou_metric: 0.7590 - val_loss: 0.1428 - val_my_iou_metric: 0.7610
#
# Epoch 00044: val_my_iou_metric did not improve from 0.76525
# Epoch 45/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0983 - my_iou_metric: 0.7640 - val_loss: 0.1428 - val_my_iou_metric: 0.7670
#
# Epoch 00045: val_my_iou_metric improved from 0.76525 to 0.76700, saving model to unet_v1_1A.model
# Epoch 46/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0992 - my_iou_metric: 0.7630 - val_loss: 0.1443 - val_my_iou_metric: 0.7695
#
# Epoch 00046: val_my_iou_metric improved from 0.76700 to 0.76950, saving model to unet_v1_1A.model
# Epoch 47/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0965 - my_iou_metric: 0.7646 - val_loss: 0.1492 - val_my_iou_metric: 0.7612
#
# Epoch 00047: val_my_iou_metric did not improve from 0.76950
# Epoch 48/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0950 - my_iou_metric: 0.7611 - val_loss: 0.1515 - val_my_iou_metric: 0.7512
#
# Epoch 00048: val_my_iou_metric did not improve from 0.76950
# Epoch 49/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0937 - my_iou_metric: 0.7650 - val_loss: 0.1646 - val_my_iou_metric: 0.7774
#
# Epoch 00049: val_my_iou_metric improved from 0.76950 to 0.77737, saving model to unet_v1_1A.model
# Epoch 50/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0951 - my_iou_metric: 0.7688 - val_loss: 0.1683 - val_my_iou_metric: 0.7588
#
# Epoch 00050: val_my_iou_metric did not improve from 0.77737
# Epoch 51/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0936 - my_iou_metric: 0.7705 - val_loss: 0.1429 - val_my_iou_metric: 0.7625
#
# Epoch 00051: val_my_iou_metric did not improve from 0.77737
# Epoch 52/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0921 - my_iou_metric: 0.7676 - val_loss: 0.1676 - val_my_iou_metric: 0.7646
#
# Epoch 00052: val_my_iou_metric did not improve from 0.77737
# Epoch 53/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0889 - my_iou_metric: 0.7757 - val_loss: 0.1962 - val_my_iou_metric: 0.7610
#
# Epoch 00053: val_my_iou_metric did not improve from 0.77737
# Epoch 54/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0901 - my_iou_metric: 0.7698 - val_loss: 0.1583 - val_my_iou_metric: 0.7450
#
# Epoch 00054: val_my_iou_metric did not improve from 0.77737
# Epoch 55/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0866 - my_iou_metric: 0.7785 - val_loss: 0.1852 - val_my_iou_metric: 0.7661
#
# Epoch 00055: val_my_iou_metric did not improve from 0.77737
# Epoch 56/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0864 - my_iou_metric: 0.7744 - val_loss: 0.1519 - val_my_iou_metric: 0.7598
#
# Epoch 00056: val_my_iou_metric did not improve from 0.77737
# Epoch 57/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0902 - my_iou_metric: 0.7746 - val_loss: 0.1390 - val_my_iou_metric: 0.7592
#
# Epoch 00057: val_my_iou_metric did not improve from 0.77737
# Epoch 58/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0884 - my_iou_metric: 0.7762 - val_loss: 0.1592 - val_my_iou_metric: 0.7707
#
# Epoch 00058: val_my_iou_metric did not improve from 0.77737
# Epoch 59/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0864 - my_iou_metric: 0.7724 - val_loss: 0.1543 - val_my_iou_metric: 0.7595
#
# Epoch 00059: val_my_iou_metric did not improve from 0.77737
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# Epoch 60/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0756 - my_iou_metric: 0.7872 - val_loss: 0.1761 - val_my_iou_metric: 0.7673
#
# Epoch 00060: val_my_iou_metric did not improve from 0.77737
# Epoch 61/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0744 - my_iou_metric: 0.7895 - val_loss: 0.1905 - val_my_iou_metric: 0.7737
#
# Epoch 00061: val_my_iou_metric did not improve from 0.77737
# Epoch 62/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0772 - my_iou_metric: 0.7877 - val_loss: 0.1653 - val_my_iou_metric: 0.7746
#
# Epoch 00062: val_my_iou_metric did not improve from 0.77737
# Epoch 63/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0740 - my_iou_metric: 0.7912 - val_loss: 0.1720 - val_my_iou_metric: 0.7657
#
# Epoch 00063: val_my_iou_metric did not improve from 0.77737
# Epoch 64/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0744 - my_iou_metric: 0.7877 - val_loss: 0.1648 - val_my_iou_metric: 0.7731
#
# Epoch 00064: val_my_iou_metric did not improve from 0.77737
# Epoch 65/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0746 - my_iou_metric: 0.7903 - val_loss: 0.1573 - val_my_iou_metric: 0.7789
#
# Epoch 00065: val_my_iou_metric improved from 0.77737 to 0.77887, saving model to unet_v1_1A.model
# Epoch 66/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0729 - my_iou_metric: 0.7890 - val_loss: 0.1922 - val_my_iou_metric: 0.7651
#
# Epoch 00066: val_my_iou_metric did not improve from 0.77887
# Epoch 67/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0702 - my_iou_metric: 0.7913 - val_loss: 0.1858 - val_my_iou_metric: 0.7766
#
# Epoch 00067: val_my_iou_metric did not improve from 0.77887
# Epoch 68/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0730 - my_iou_metric: 0.7856 - val_loss: 0.1608 - val_my_iou_metric: 0.7721
#
# Epoch 00068: val_my_iou_metric did not improve from 0.77887
# Epoch 69/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0723 - my_iou_metric: 0.7875 - val_loss: 0.1547 - val_my_iou_metric: 0.7764
#
# Epoch 00069: val_my_iou_metric did not improve from 0.77887
# Epoch 70/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0708 - my_iou_metric: 0.7908 - val_loss: 0.1899 - val_my_iou_metric: 0.7800
#
# Epoch 00070: val_my_iou_metric improved from 0.77887 to 0.78000, saving model to unet_v1_1A.model
# Epoch 71/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0678 - my_iou_metric: 0.7942 - val_loss: 0.1763 - val_my_iou_metric: 0.7699
# Epoch 00071: val_my_iou_metric did not improve from 0.78000
# Epoch 72/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0706 - my_iou_metric: 0.7894 - val_loss: 0.1690 - val_my_iou_metric: 0.7775
#
# Epoch 00072: val_my_iou_metric did not improve from 0.78000
# Epoch 73/300
# 6400/6400 [==============================] - 81s 13ms/step - loss: 0.0703 - my_iou_metric: 0.7947 - val_loss: 0.1648 - val_my_iou_metric: 0.7665
#
# Epoch 00073: val_my_iou_metric did not improve from 0.78000
# Epoch 74/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0673 - my_iou_metric: 0.7921 - val_loss: 0.1813 - val_my_iou_metric: 0.7801
#
# Epoch 00074: val_my_iou_metric improved from 0.78000 to 0.78013, saving model to unet_v1_1A.model
# Epoch 75/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0677 - my_iou_metric: 0.7958 - val_loss: 0.1846 - val_my_iou_metric: 0.7811
#
# Epoch 00075: val_my_iou_metric improved from 0.78013 to 0.78112, saving model to unet_v1_1A.model
# Epoch 76/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0667 - my_iou_metric: 0.7992 - val_loss: 0.1608 - val_my_iou_metric: 0.7754
#
# Epoch 00076: val_my_iou_metric did not improve from 0.78112
# Epoch 77/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0657 - my_iou_metric: 0.7977 - val_loss: 0.1809 - val_my_iou_metric: 0.7839
#
# Epoch 00077: val_my_iou_metric improved from 0.78112 to 0.78387, saving model to unet_v1_1A.model
# Epoch 78/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0653 - my_iou_metric: 0.7998 - val_loss: 0.1697 - val_my_iou_metric: 0.7777
#
# Epoch 00078: val_my_iou_metric did not improve from 0.78387
# Epoch 79/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0708 - my_iou_metric: 0.7968 - val_loss: 0.1805 - val_my_iou_metric: 0.7661
#
# Epoch 00079: val_my_iou_metric did not improve from 0.78387
# Epoch 80/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0638 - my_iou_metric: 0.8006 - val_loss: 0.2178 - val_my_iou_metric: 0.7871
#
# Epoch 00080: val_my_iou_metric improved from 0.78387 to 0.78713, saving model to unet_v1_1A.model
# Epoch 81/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0639 - my_iou_metric: 0.7998 - val_loss: 0.2157 - val_my_iou_metric: 0.7778
#
# Epoch 00081: val_my_iou_metric did not improve from 0.78713
# Epoch 82/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0660 - my_iou_metric: 0.7991 - val_loss: 0.2274 - val_my_iou_metric: 0.7828
#
# Epoch 00082: val_my_iou_metric did not improve from 0.78713
# Epoch 83/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0654 - my_iou_metric: 0.8012 - val_loss: 0.2049 - val_my_iou_metric: 0.7721
#
# Epoch 00083: val_my_iou_metric did not improve from 0.78713
# Epoch 84/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0633 - my_iou_metric: 0.8006 - val_loss: 0.1905 - val_my_iou_metric: 0.7752
#
# Epoch 00084: val_my_iou_metric did not improve from 0.78713
# Epoch 85/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0635 - my_iou_metric: 0.8018 - val_loss: 0.1920 - val_my_iou_metric: 0.7678
#
# Epoch 00085: val_my_iou_metric did not improve from 0.78713
# Epoch 86/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0649 - my_iou_metric: 0.8010 - val_loss: 0.1944 - val_my_iou_metric: 0.7815
#
# Epoch 00086: val_my_iou_metric did not improve from 0.78713
# Epoch 87/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0613 - my_iou_metric: 0.8058 - val_loss: 0.1909 - val_my_iou_metric: 0.7766
#
# Epoch 00087: val_my_iou_metric did not improve from 0.78713
# Epoch 88/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0601 - my_iou_metric: 0.8070 - val_loss: 0.1863 - val_my_iou_metric: 0.7786
#
# Epoch 00088: val_my_iou_metric did not improve from 0.78713
# Epoch 89/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0624 - my_iou_metric: 0.8030 - val_loss: 0.1704 - val_my_iou_metric: 0.7704
#
# Epoch 00089: val_my_iou_metric did not improve from 0.78713
# Epoch 90/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0640 - my_iou_metric: 0.8026 - val_loss: 0.2076 - val_my_iou_metric: 0.7761
#
# Epoch 00090: val_my_iou_metric did not improve from 0.78713
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# Epoch 91/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0572 - my_iou_metric: 0.8076 - val_loss: 0.1953 - val_my_iou_metric: 0.7877
#
# Epoch 00091: val_my_iou_metric improved from 0.78713 to 0.78775, saving model to unet_v1_1A.model
# Epoch 92/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0551 - my_iou_metric: 0.8140 - val_loss: 0.2240 - val_my_iou_metric: 0.7794
#
# Epoch 00092: val_my_iou_metric did not improve from 0.78775
# Epoch 93/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0540 - my_iou_metric: 0.8131 - val_loss: 0.2190 - val_my_iou_metric: 0.7836
#
# Epoch 00093: val_my_iou_metric did not improve from 0.78775
# Epoch 94/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0560 - my_iou_metric: 0.8134 - val_loss: 0.2070 - val_my_iou_metric: 0.7900
#
# Epoch 00094: val_my_iou_metric improved from 0.78775 to 0.79000, saving model to unet_v1_1A.model
# Epoch 95/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0531 - my_iou_metric: 0.8148 - val_loss: 0.1818 - val_my_iou_metric: 0.7797
#
# Epoch 00095: val_my_iou_metric did not improve from 0.79000
# Epoch 96/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0544 - my_iou_metric: 0.8130 - val_loss: 0.2102 - val_my_iou_metric: 0.7774
#
# Epoch 00096: val_my_iou_metric did not improve from 0.79000
# Epoch 97/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0539 - my_iou_metric: 0.8140 - val_loss: 0.1905 - val_my_iou_metric: 0.7841
#
# Epoch 00097: val_my_iou_metric did not improve from 0.79000
# Epoch 98/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0537 - my_iou_metric: 0.8188 - val_loss: 0.1977 - val_my_iou_metric: 0.7839
#
# Epoch 00098: val_my_iou_metric did not improve from 0.79000
# Epoch 99/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0553 - my_iou_metric: 0.8158 - val_loss: 0.1965 - val_my_iou_metric: 0.7845
#
# Epoch 00099: val_my_iou_metric did not improve from 0.79000
# Epoch 100/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0525 - my_iou_metric: 0.8149 - val_loss: 0.1971 - val_my_iou_metric: 0.7776
#
# Epoch 00100: val_my_iou_metric did not improve from 0.79000
# Epoch 101/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0529 - my_iou_metric: 0.8168 - val_loss: 0.1978 - val_my_iou_metric: 0.7835
#
# Epoch 00101: val_my_iou_metric did not improve from 0.79000
# Epoch 102/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0514 - my_iou_metric: 0.8195 - val_loss: 0.2223 - val_my_iou_metric: 0.7816
#
# Epoch 00102: val_my_iou_metric did not improve from 0.79000
# Epoch 103/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0507 - my_iou_metric: 0.8193 - val_loss: 0.1993 - val_my_iou_metric: 0.7784
#
# Epoch 00103: val_my_iou_metric did not improve from 0.79000
# Epoch 104/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0522 - my_iou_metric: 0.8203 - val_loss: 0.2144 - val_my_iou_metric: 0.7837
#
# Epoch 00104: val_my_iou_metric did not improve from 0.79000
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# Epoch 105/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0507 - my_iou_metric: 0.8207 - val_loss: 0.2084 - val_my_iou_metric: 0.7825
#
# Epoch 00105: val_my_iou_metric did not improve from 0.79000
# Epoch 106/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0503 - my_iou_metric: 0.8191 - val_loss: 0.2035 - val_my_iou_metric: 0.7803
#
# Epoch 00106: val_my_iou_metric did not improve from 0.79000
# Epoch 107/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0499 - my_iou_metric: 0.8194 - val_loss: 0.2392 - val_my_iou_metric: 0.7870
#
# Epoch 00107: val_my_iou_metric did not improve from 0.79000
# Epoch 108/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0490 - my_iou_metric: 0.8209 - val_loss: 0.2177 - val_my_iou_metric: 0.7859
#
# Epoch 00108: val_my_iou_metric did not improve from 0.79000
# Epoch 109/300
# 6400/6400 [==============================] - 80s 12ms/step - loss: 0.0468 - my_iou_metric: 0.8259 - val_loss: 0.2200 - val_my_iou_metric: 0.7826
#
# Epoch 00109: val_my_iou_metric did not improve from 0.79000
# Epoch 110/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0483 - my_iou_metric: 0.8222 - val_loss: 0.2042 - val_my_iou_metric: 0.7844
#
# Epoch 00110: val_my_iou_metric did not improve from 0.79000
# Epoch 111/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0476 - my_iou_metric: 0.8209 - val_loss: 0.2311 - val_my_iou_metric: 0.7850
#
# Epoch 00111: val_my_iou_metric did not improve from 0.79000
# Epoch 112/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0470 - my_iou_metric: 0.8252 - val_loss: 0.2019 - val_my_iou_metric: 0.7864
#
# Epoch 00112: val_my_iou_metric did not improve from 0.79000
# Epoch 113/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0469 - my_iou_metric: 0.8244 - val_loss: 0.2283 - val_my_iou_metric: 0.7781
#
# Epoch 00113: val_my_iou_metric did not improve from 0.79000
# Epoch 114/300
# 6400/6400 [==============================] - 80s 13ms/step - loss: 0.0469 - my_iou_metric: 0.8268 - val_loss: 0.2190 - val_my_iou_metric: 0.7849
#
# Epoch 00114: val_my_iou_metric did not improve from 0.79000
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 0.0007775999838486314.
# Epoch 00114: early stopping

# %% [markdown]
# # Remove later activation layer and use losvasz loss
#
# #lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.

# %%
model1 = load_model(save_model_name, custom_objects={'my_iou_metric': my_iou_metric})

input_x = model1.layers[0].input
output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
# c = optimizers.Adam(lr = 0.01)
c = optimizers.RMSprop(lr=0.01)
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()

# %% [markdown]
# # Set hyperparameters

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode='max', patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_nameB, monitor='val_my_iou_metric_2', mode='max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode='max',factor=0.6, patience=10, min_lr=0.0001, verbose=1)

epochs = 300
batch_size = 32

# %% [markdown]
# # Train

# %%
# %%time
history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[model_checkpoint, reduce_lr, early_stopping], 
                    verbose=1)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/300
# 6400/6400 [==============================] - 213s 33ms/step - loss: -0.0482 - my_iou_metric_2: 0.7845 - val_loss: 0.5005 - val_my_iou_metric_2: 0.7260
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.72600, saving model to unet_v1_1B.model
# Epoch 2/300
# 6400/6400 [==============================] - 199s 31ms/step - loss: -0.1003 - my_iou_metric_2: 0.7893 - val_loss: 0.0074 - val_my_iou_metric_2: 0.7760
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.72600 to 0.77600, saving model to unet_v1_1B.model
# Epoch 3/300
# 6400/6400 [==============================] - 198s 31ms/step - loss: -0.1177 - my_iou_metric_2: 0.7922 - val_loss: 0.0527 - val_my_iou_metric_2: 0.7573
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 4/300
# 6400/6400 [==============================] - 191s 30ms/step - loss: -0.1375 - my_iou_metric_2: 0.7957 - val_loss: 0.0275 - val_my_iou_metric_2: 0.7742
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 5/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1446 - my_iou_metric_2: 0.7943 - val_loss: 0.0615 - val_my_iou_metric_2: 0.7731
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 6/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1648 - my_iou_metric_2: 0.8000 - val_loss: 0.1100 - val_my_iou_metric_2: 0.7729
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 7/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1691 - my_iou_metric_2: 0.8010 - val_loss: 0.0197 - val_my_iou_metric_2: 0.7719
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 8/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1828 - my_iou_metric_2: 0.8051 - val_loss: -0.0011 - val_my_iou_metric_2: 0.7716
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 9/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1771 - my_iou_metric_2: 0.8017 - val_loss: 0.3404 - val_my_iou_metric_2: 0.7226
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.77600
# Epoch 10/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1769 - my_iou_metric_2: 0.8003 - val_loss: 0.0174 - val_my_iou_metric_2: 0.7797
#
# Epoch 00010: val_my_iou_metric_2 improved from 0.77600 to 0.77975, saving model to unet_v1_1B.model
# Epoch 11/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.1929 - my_iou_metric_2: 0.8011 - val_loss: 0.0570 - val_my_iou_metric_2: 0.7602
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.77975
# Epoch 12/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2217 - my_iou_metric_2: 0.8092 - val_loss: -0.0116 - val_my_iou_metric_2: 0.7735
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.77975
# Epoch 13/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2181 - my_iou_metric_2: 0.8085 - val_loss: -0.0194 - val_my_iou_metric_2: 0.7946
#
# Epoch 00013: val_my_iou_metric_2 improved from 0.77975 to 0.79462, saving model to unet_v1_1B.model
# Epoch 14/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2362 - my_iou_metric_2: 0.8109 - val_loss: -0.0477 - val_my_iou_metric_2: 0.7871
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 15/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2271 - my_iou_metric_2: 0.8111 - val_loss: -0.0646 - val_my_iou_metric_2: 0.7921
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 16/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2441 - my_iou_metric_2: 0.8149 - val_loss: 0.0388 - val_my_iou_metric_2: 0.7734
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 17/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2392 - my_iou_metric_2: 0.8130 - val_loss: -0.0788 - val_my_iou_metric_2: 0.7889
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 18/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2481 - my_iou_metric_2: 0.8141 - val_loss: -0.0072 - val_my_iou_metric_2: 0.7928
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 19/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2627 - my_iou_metric_2: 0.8183 - val_loss: -0.0749 - val_my_iou_metric_2: 0.7869
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.79462
# Epoch 20/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2553 - my_iou_metric_2: 0.8140 - val_loss: -0.0534 - val_my_iou_metric_2: 0.7990
#
# Epoch 00020: val_my_iou_metric_2 improved from 0.79462 to 0.79900, saving model to unet_v1_1B.model
# Epoch 21/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2697 - my_iou_metric_2: 0.8177 - val_loss: 0.0651 - val_my_iou_metric_2: 0.7786
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 22/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2713 - my_iou_metric_2: 0.8184 - val_loss: -0.0182 - val_my_iou_metric_2: 0.7799
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 23/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2781 - my_iou_metric_2: 0.8201 - val_loss: -0.0427 - val_my_iou_metric_2: 0.7875
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 24/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2859 - my_iou_metric_2: 0.8189 - val_loss: 0.0088 - val_my_iou_metric_2: 0.7744
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 25/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2921 - my_iou_metric_2: 0.8230 - val_loss: 0.0271 - val_my_iou_metric_2: 0.7856
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 26/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.2945 - my_iou_metric_2: 0.8220 - val_loss: 0.0187 - val_my_iou_metric_2: 0.7747
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 27/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3072 - my_iou_metric_2: 0.8234 - val_loss: -0.0530 - val_my_iou_metric_2: 0.7862
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 28/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3055 - my_iou_metric_2: 0.8236 - val_loss: -0.0137 - val_my_iou_metric_2: 0.7916
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 29/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3017 - my_iou_metric_2: 0.8241 - val_loss: 5.7618e-04 - val_my_iou_metric_2: 0.7877
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 30/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3086 - my_iou_metric_2: 0.8257 - val_loss: -0.0056 - val_my_iou_metric_2: 0.7941
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.79900
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.005999999865889549.
# Epoch 31/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3624 - my_iou_metric_2: 0.8363 - val_loss: 0.0149 - val_my_iou_metric_2: 0.7940
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 32/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3916 - my_iou_metric_2: 0.8419 - val_loss: -0.0182 - val_my_iou_metric_2: 0.7985
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.79900
# Epoch 33/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3927 - my_iou_metric_2: 0.8416 - val_loss: -0.0567 - val_my_iou_metric_2: 0.8025
#
# Epoch 00033: val_my_iou_metric_2 improved from 0.79900 to 0.80250, saving model to unet_v1_1B.model
# Epoch 34/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.3850 - my_iou_metric_2: 0.8379 - val_loss: -0.0604 - val_my_iou_metric_2: 0.8075
#
# Epoch 00034: val_my_iou_metric_2 improved from 0.80250 to 0.80750, saving model to unet_v1_1B.model
# Epoch 35/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4041 - my_iou_metric_2: 0.8462 - val_loss: 0.0462 - val_my_iou_metric_2: 0.7844
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 36/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4117 - my_iou_metric_2: 0.8436 - val_loss: 0.0107 - val_my_iou_metric_2: 0.7966
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 37/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4058 - my_iou_metric_2: 0.8444 - val_loss: 0.0033 - val_my_iou_metric_2: 0.7872
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 38/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4023 - my_iou_metric_2: 0.8431 - val_loss: -0.0346 - val_my_iou_metric_2: 0.8022
#
# Epoch 00038: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 39/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4223 - my_iou_metric_2: 0.8474 - val_loss: 0.0103 - val_my_iou_metric_2: 0.7964
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 40/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4126 - my_iou_metric_2: 0.8467 - val_loss: -0.0134 - val_my_iou_metric_2: 0.8051
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 41/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4208 - my_iou_metric_2: 0.8476 - val_loss: 0.0250 - val_my_iou_metric_2: 0.7915
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 42/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4284 - my_iou_metric_2: 0.8485 - val_loss: 0.0376 - val_my_iou_metric_2: 0.8012
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 43/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4238 - my_iou_metric_2: 0.8464 - val_loss: -0.0027 - val_my_iou_metric_2: 0.8037
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.80750
# Epoch 44/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4333 - my_iou_metric_2: 0.8484 - val_loss: 0.0117 - val_my_iou_metric_2: 0.7947
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.80750
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.003600000031292438.
# Epoch 45/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4716 - my_iou_metric_2: 0.8583 - val_loss: -0.0156 - val_my_iou_metric_2: 0.8077
#
# Epoch 00045: val_my_iou_metric_2 improved from 0.80750 to 0.80775, saving model to unet_v1_1B.model
# Epoch 46/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4810 - my_iou_metric_2: 0.8574 - val_loss: 0.0214 - val_my_iou_metric_2: 0.8068
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.80775
# Epoch 47/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4769 - my_iou_metric_2: 0.8568 - val_loss: 0.0956 - val_my_iou_metric_2: 0.7996
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.80775
# Epoch 48/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4860 - my_iou_metric_2: 0.8589 - val_loss: 0.0245 - val_my_iou_metric_2: 0.8090
#
# Epoch 00048: val_my_iou_metric_2 improved from 0.80775 to 0.80900, saving model to unet_v1_1B.model
# Epoch 49/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4864 - my_iou_metric_2: 0.8582 - val_loss: 0.0572 - val_my_iou_metric_2: 0.8101
#
# Epoch 00049: val_my_iou_metric_2 improved from 0.80900 to 0.81012, saving model to unet_v1_1B.model
# Epoch 50/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4998 - my_iou_metric_2: 0.8614 - val_loss: -0.0141 - val_my_iou_metric_2: 0.8118
#
# Epoch 00050: val_my_iou_metric_2 improved from 0.81012 to 0.81175, saving model to unet_v1_1B.model
# Epoch 51/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.4928 - my_iou_metric_2: 0.8581 - val_loss: 0.0205 - val_my_iou_metric_2: 0.8134
#
# Epoch 00051: val_my_iou_metric_2 improved from 0.81175 to 0.81338, saving model to unet_v1_1B.model
# Epoch 52/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5039 - my_iou_metric_2: 0.8605 - val_loss: 0.0793 - val_my_iou_metric_2: 0.8131
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 53/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5007 - my_iou_metric_2: 0.8606 - val_loss: 0.0770 - val_my_iou_metric_2: 0.8026
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 54/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5062 - my_iou_metric_2: 0.8609 - val_loss: 0.1523 - val_my_iou_metric_2: 0.8088
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 55/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5096 - my_iou_metric_2: 0.8626 - val_loss: 0.0150 - val_my_iou_metric_2: 0.7995
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 56/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5029 - my_iou_metric_2: 0.8611 - val_loss: 0.0668 - val_my_iou_metric_2: 0.8118
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 57/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5097 - my_iou_metric_2: 0.8623 - val_loss: 0.0575 - val_my_iou_metric_2: 0.7955
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 58/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5106 - my_iou_metric_2: 0.8633 - val_loss: 0.0653 - val_my_iou_metric_2: 0.8044
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 59/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5157 - my_iou_metric_2: 0.8633 - val_loss: 0.0981 - val_my_iou_metric_2: 0.8021
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 60/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5156 - my_iou_metric_2: 0.8631 - val_loss: 0.0330 - val_my_iou_metric_2: 0.8115
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 61/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5176 - my_iou_metric_2: 0.8625 - val_loss: 0.1220 - val_my_iou_metric_2: 0.8000
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.81338
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.0021599999628961085.
# Epoch 62/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5320 - my_iou_metric_2: 0.8676 - val_loss: 0.0252 - val_my_iou_metric_2: 0.8094
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 63/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5429 - my_iou_metric_2: 0.8677 - val_loss: 0.1087 - val_my_iou_metric_2: 0.8131
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 64/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5470 - my_iou_metric_2: 0.8688 - val_loss: 0.1055 - val_my_iou_metric_2: 0.8089
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 65/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5391 - my_iou_metric_2: 0.8666 - val_loss: 0.0982 - val_my_iou_metric_2: 0.8114
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 66/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5465 - my_iou_metric_2: 0.8679 - val_loss: 0.0610 - val_my_iou_metric_2: 0.8103
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 67/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5490 - my_iou_metric_2: 0.8698 - val_loss: 0.1098 - val_my_iou_metric_2: 0.8046
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 68/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5560 - my_iou_metric_2: 0.8700 - val_loss: 0.1479 - val_my_iou_metric_2: 0.8120
#
# Epoch 00068: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 69/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5524 - my_iou_metric_2: 0.8714 - val_loss: 0.1880 - val_my_iou_metric_2: 0.8081
# Epoch 00069: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 70/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5575 - my_iou_metric_2: 0.8710 - val_loss: 0.1368 - val_my_iou_metric_2: 0.8041
#
# Epoch 00070: val_my_iou_metric_2 did not improve from 0.81338
# Epoch 71/300
# 6400/6400 [==============================] - 188s 29ms/step - loss: -0.5634 - my_iou_metric_2: 0.8711 - val_loss: 0.1922 - val_my_iou_metric_2: 0.8064
#
# Epoch 00071: val_my_iou_metric_2 did not improve from 0.81338
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 0.0012959999497979878.
# Epoch 00071: early stopping

# %% [markdown]
# # Plot Result

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))

ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()

ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")

ax_score.legend()

# %% [markdown]
# # Predict on Test Data

# %%
model = load_model(save_model_nameB,custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                   'lovasz_loss': lovasz_loss})

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
preds_valid = predict_result(model,x_valid,img_size_target)

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))

    intersection = temp1[0]

    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
      
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
## Scoring for last model, choose threshold by validation data 
thresholds_ori = np.linspace(0.3, 0.7, 31)
# Reverse sigmoid function: Use code below because the  sigmoid activation was removed
thresholds = np.log(thresholds_ori/(1-thresholds_ori)) 

# ious = np.array([get_iou_vector(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
# print(ious)
ious = np.array([iou_metric_batch(y_valid, preds_valid > threshold) for threshold in tqdm_notebook(thresholds)])
print(ious)
# Out:
# HBox(children=(IntProgress(value=0, max=31), HTML(value='')))
# [0.8045   0.80475  0.805    0.805    0.805375 0.80575  0.80625  0.807625
#  0.80925  0.810625 0.811875 0.812625 0.81225  0.812125 0.81275  0.812125
#  0.81125  0.812125 0.8115   0.810875 0.810375 0.81275  0.81275  0.812
#  0.8115   0.811    0.813    0.81225  0.812875 0.8125   0.811875]

# %%
# instead of using default 0 as threshold, use validation data to find the best threshold.
threshold_best_index = np.argmax(ious) 
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
# x_test = np.array([(np.array(load_img("data/salt/test/images/{}.png".format(idx), grayscale = True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)

# %%
test_img_list = []

for idx in tqdm_notebook(test_df.index):
    test_img = load_img(f"{DATA_DIR}test/images/{idx}.png", grayscale=True)
    test_img_list.append((np.array(test_img)-train_data_mean)/train_data_std)
    
x_test=np.array(test_img_list).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
x_test.shape
# Out:
# (18000, 101, 101, 1)

# %%
# %%time
preds_test = predict_result(model,x_test,img_size_target)

# %%
t1 = time.time()
pred_dict = {idx: rle_encode(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
t2 = time.time()

print(f"Usedtime = {t2-t1} s")
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# Usedtime = 6.371180057525635 s

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv(submission_file)

# %%
t_finish = time.time()
print(f"Kernel run time = {(t_finish-t_start)/3600} hours")
# Out:
# Kernel run time = 7.145853833225038 hours

# %%
# !kaggle competitions submit tgs-salt-identification-challenge -f f{submission_file} -m "unet_v1_1"
# Out:
# /bin/sh: 1: kaggle: not found
